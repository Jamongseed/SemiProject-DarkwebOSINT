# %%
from bs4 import BeautifulSoup
from pprint import pprint
import requests
from datetime import datetime, timezone
from zoneinfo import ZoneInfo

# %%
def get_html_sync(url: str, timeout: int = 10) -> str | None:
    """
    주어진 URL의 HTML 콘텐츠를 동기적으로 가져옴

    :param url: HTML을 가져올 웹사이트 URL
    :param timeout: 요청 대기 시간 (초)
    :return: 성공 시 HTML 텍스트, 실패 시 None
    """
    try:
        # User-Agent를 설정하여 봇으로 인식되는 것을 방지
        headers = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
        }
        
        # requests.get을 사용하여 URL에 GET 요청을 보냄
        response = requests.get(url, headers=headers, timeout=timeout)
        
        # HTTP 상태 코드가 200 (OK)이 아닐 경우 예외를 발생
        response.raise_for_status()
        
        print(f"✅ [{url}] - 동기 호출 성공")
        return response.text
    
    except Exception as e:
        # 모든 requests 관련 예외를 처리
        print(f"❌ [{url}] - 오류 발생: {e}")
        return None

# --- 함수 사용 예시 ---
URL = "https://www.ransomware.live/"
html_content = get_html_sync(URL)
print(html_content)
# Out:
# ✅ [https://www.ransomware.live/] - 동기 호출 성공
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <!--
#
# ██████╗  █████╗ ███╗   ██╗███████╗ ██████╗ ███╗   ███╗██╗    ██╗ █████╗ ██████╗ ███████╗   ██╗     ██╗██╗   ██╗███████╗
# ██╔══██╗██╔══██╗████╗  ██║██╔════╝██╔═══██╗████╗ ████║██║    ██║██╔══██╗██╔══██╗██╔════╝   ██║     ██║██║   ██║██╔════╝
# ██████╔╝███████║██╔██╗ ██║███████╗██║   ██║██╔████╔██║██║ █╗ ██║███████║██████╔╝█████╗     ██║     ██║██║   ██║█████╗
# ██╔══██╗██╔══██║██║╚██╗██║╚════██║██║   ██║██║╚██╔╝██║██║███╗██║██╔══██║██╔══██╗██╔══╝     ██║     ██║╚██╗ ██╔╝██╔══╝
# ██║  ██║██║  ██║██║ ╚████║███████║╚██████╔╝██║ ╚═╝ ██║╚███╔███╔╝██║  ██║██║  ██║███████╗██╗███████╗██║ ╚████╔╝ ███████╗
# ╚═╝  ╚═╝╚═╝  ╚═╝╚═╝  ╚═══╝╚══════╝ ╚═════╝ ╚═╝     ╚═╝ ╚══╝╚══╝ ╚═╝  ╚═╝╚═╝  ╚═╝╚══════╝╚═╝╚══════╝╚═╝  ╚═══╝  ╚══════╝
# Non nobis, sed securitati communi
#
# version 2025-08 - BSides Bournemouth Edition
# by Julien Mousqueton
#   Contact : @JMousqueton on X (Twitter) or @Julien.io on BlueSky
#
# -->
# <meta charset="UTF-8">
#
# <meta name="description" content="Ransomware.live tracks & monitors ransomware groups' victims and their activity. It was created by Julien Mousqueton, a security researcher. The website provides information on Ransomware groups, victims, negotiations, and payment demands. It also includes the latest cyberattacks.">
# <meta name="keywords" content="ransomware, API, RSS, breach, leak, post, gang, data, tracking, tracker, Monitoring, monitor, victim, group, ransom, ransomwatch, julien, mousqueton, julien mousqueton, CyberSoc, CTI, negotiations, ransomnote, IOC, Yara, TTPs, soc">
# <!-- Open Graph / Facebook -->
# <meta property="og:type" content="website">
# <meta property="og:url" content="https://www.ransomware.live">
# <meta property="og:title" content="Ransomware.live 👀">
# <meta property="og:description" content="Ransomware.live tracks ransomware groups and their activity. It was created by Julien Mousqueton, a security researcher. The website provides information on the groups' infrastructure, victims, and payment demands. It also includes a live map that shows the latest ransomware attacks.">
# <meta property="og:image" content="https://images.ransomware.live/ransomware.png">
# <!-- Twitter -->
# <meta property="twitter:card" content="summary_large_image">
# <meta property="twitter:url" content="https://www.ransomware.live/">
# <meta property="twitter:title" content="Ransomware.live 👀">
# <meta property="twitter:description" content="Ransomware.live tracks & monitors ransomware groups' victims and their activity. It was created by Julien Mousqueton, a security researcher. The website provides information on Ransomware groups, victims, negotiations, and payment demands. It also includes the latest cyberattacks.">
# <meta property="twitter:image" content="https://images.ransomware.live/ransomware.png">
# <meta name="viewport" content="width=device-width, initial-scale=1.0, minimum-scale=1.0">
#
#
# <script src="https://analytics.ahrefs.com/analytics.js" data-key="rZDXtX7O0vcNFZ1mlZ79UA" async></script>
# <link href="/static/style.css" rel="stylesheet" />
#
# <style>
#   .text-muted-light {
#     color: rgba(108, 117, 125, 0.3); /* Bootstrap's muted color with reduced opacity */
#   }
#   .ribbon {
#     position: absolute;
#     top: 0;
#     left: 0;
#     background: red;
#     color: white;
#     padding: 0.25rem 0.5rem;
#     font-size: 0.5rem;
#     font-weight: bold;
#     border-bottom-right-radius: 0.5rem;
#     z-index: 10;
#   }
# .navbar-nav .nav-link {
#   padding: 0.5rem 0.75rem;
#   font-weight: 500;
#   border-radius: 0.375rem;
#   transition: background-color 0.3s ease, color 0.3s ease, transform 0.2s ease;
# }
#
# .navbar-nav .nav-link:hover {
#   background-color: rgba(60, 179, 113, 0.15);
#   color: #ffffff !important;
#   transform: translateY(-1px);
#   box-shadow: 0 2px 6px rgba(60, 179, 113, 0.15);
# }
#
# .navbar-nav .nav-link i {
#   margin-right: 0.4rem;
# }
#
# </style>
#
#
#
#
# <title></title>
# <!-- Favicon -->
# <link rel="icon" href="/static/favicon.ico" type="image/x-icon">
#
#   <meta charset="UTF-8" />
#   <meta name="viewport" content="width=device-width, initial-scale=1" />
#   <link href="https://cdn.jsdelivr.net/npm/bootstrap@5.3.3/dist/css/bootstrap.min.css" rel="stylesheet" />
#   <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.3.3/dist/js/bootstrap.bundle.min.js"></script>
#
#   <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.6.0/css/all.min.css">
#
#   <link rel="manifest" href="/manifest.json">
#   <meta name="theme-color" content="#3CB371">
#   <link rel="apple-touch-icon" href="/static/icons/icon-192.png">
# </head>
#
# <body class="d-flex flex-column min-vh-100" data-bs-theme="light">
#   <script>
#     const savedTheme = document.cookie.match(/(?:^|; )theme=([^;]*)/)?.[1] || 'light';
#     document.body.setAttribute("data-bs-theme", savedTheme);
#   </script>
# <!-- 3CB371 -->
# <nav class="navbar navbar-dark" style="background: linear-gradient(to right, #ffffff, #5fad82); min-height: 100px;">
#   <div class="container-fluid d-flex flex-column justify-content-between" style="min-height: 100px; width: 100%;">
#
#     <!-- Top: Logo + Hamburger + Main Menu -->
#     <div class="d-flex justify-content-between align-items-center w-100">
#       <!-- Logo -->
#       <a class="navbar-brand d-flex align-items-center" href="/">
#         <img src="https://images.ransomware.live/logo.png"
#              alt="Ransomware.live Logo"
#              style="height: 128px; width: auto; margin-right: 10px; border-radius: 4px; padding: 2px;" />
#       </a>
#
#       <!-- Hamburger (mobile only) -->
#       <div class="position-relative d-lg-none">
#         <button class="navbar-toggler" type="button" id="menuToggle" aria-expanded="false" aria-label="Toggle navigation">
#           <span class="navbar-toggler-icon"></span>
#         </button>
#
#         <!-- Mobile Dropdown Menu -->
#         <ul id="mobileMenu"
#             class="dropdown-menu p-2 shadow"
#             style="display: none; position: absolute; right: 0; top: 100%; min-width: max-content; z-index: 1000;">
#           <li><a class="dropdown-item" href="/summary">🎯 Victims</a></li>
#           <li><a class="dropdown-item" href="/groups">🏠 Groups</a></li>
#           <li><a class="dropdown-item" href="/press">🗞️ Press</a></li>
#           <li><a class="dropdown-item" href="/statistics">📊 Statistics</a></li>
#           <li><a class="dropdown-item" href="/worldmap">🌍 Worldmap</a></li>
#           <li><a class="dropdown-item" href="/nego">💬 Negotiations</a></li>
#           <li><a class="dropdown-item" href="/search">🔎 Search</a></li>
#           <li><a class="dropdown-item" href="/notification">🔔 Notifications</a></li>
#           <li><a class="dropdown-item" href="/about">ℹ️ About</a></li>
#           <li><a class="dropdown-item" href="https://buymeacoffee.com/ransomwarelive" target="_blank">☕️ Buy me a coffee</a></li>
#           <li>
#             <button class="dropdown-item" data-bs-toggle="modal" data-bs-target="#legendModal">🛟 Legend</button>
#           </li>
#           <li>
#             <a href="#" id="theme-toggle-mobile" class="dropdown-item d-flex align-items-center">
#               <i id="theme-toggle-icon-mobile" class="fa-solid fa-toggle-on me-2"></i> Toggle Mode
#             </a>
#           </li>
#         </ul>
#       </div>
#
# <!-- Desktop stacked menu (still aligned with the logo) -->
# <div class="d-none d-lg-flex flex-column align-items-end justify-content-center">
#   <!-- Top row of links -->
#   <ul class="navbar-nav flex-row gap-3 mb-1">
#     <li class="nav-item">
#       <a class="nav-link text-dark d-flex flex-column align-items-center justify-content-center text-center" href="/">
#         <i class="fa-solid fa-bullseye fs-4 mb-1"></i>
#         <span>Victims</span>
#       </a>
#     </li>
#     <li class="nav-item">
#       <a class="nav-link text-dark d-flex flex-column align-items-center justify-content-center text-center" href="/groups">
#         <i class="fa-solid fa-users fs-4 mb-1"></i>
#         <span>Groups</span>
#       </a>
#     </li>
#     <li class="nav-item">
#       <a class="nav-link text-dark d-flex flex-column align-items-center justify-content-center text-center" href="/cyberattacks">
#         <i class="fa-solid fa-newspaper fs-4 mb-1"></i>
#         <span>Press</span>
#       </a>
#     </li>
#     <li class="nav-item">
#       <a class="nav-link text-dark d-flex flex-column align-items-center justify-content-center text-center" href="/search">
#         <i class="fa-solid fa-magnifying-glass fs-4 mb-1"></i>
#         <span>Search</span>
#       </a>
#     </li>
#     <li class="nav-item">
#       <a class="nav-link text-dark d-flex flex-column align-items-center justify-content-center text-center" href="/stats">
#         <i class="fa-solid fa-chart-bar fs-4 mb-1"></i>
#         <span>Statistics</span>
#       </a>
#     </li>
#     <li class="nav-item">
#       <a class="nav-link text-dark d-flex flex-column align-items-center justify-content-center text-center" href="/map">
#         <i class="fa-solid fa-globe fs-4 mb-1"></i>
#         <span>Worldmap</span>
#       </a>
#     </li>
#
#
#
#
# <li class="nav-item">
#   <a class="nav-link text-dark d-flex flex-column align-items-center justify-content-center text-center"
#      href="/quadrants#2025">
#     <i class="fa-solid fa-ranking-star fs-4 mb-1"></i>
#     <span>Quadrants</span>
#   </a>
# </li>
#     <li class="nav-item">
#       <a class="nav-link text-dark d-flex flex-column align-items-center justify-content-center text-center" href="/about">
#         <i class="fa-solid fa-circle-info fs-4 mb-1"></i>
#         <span>About</span>
#       </a>
#     </li>
#     <li class="nav-item mx-3"></li>
#     <li class="nav-item"><button type="button"
#               class="btn btn-link text-dark d-flex flex-column align-items-center justify-content-center text-center p-0 m-0"
#               data-bs-toggle="modal"
#               data-bs-target="#legendModal"
#               style="text-decoration: none;"
#               title="Legend"><i class="fa-solid fa-circle-question fs-4 mb-1"></i></button></li>
#   </ul>
#
#   <!-- Second row of links -->
#   <ul class="navbar-nav flex-row gap-3">
#     <li class="nav-item">
#       <a class="nav-link text-dark d-flex flex-column align-items-center justify-content-center text-center" href="/nego">
#         <i class="fa-solid fa-comments fs-4 mb-1"></i>
#         <span>Negotiations</span>
#       </a>
#     </li>
#     <li class="nav-item">
#       <a class="nav-link text-dark d-flex flex-column align-items-center justify-content-center text-center" href="/ransomnotes">
#         <i class="fa-solid fa-file-lines fs-4 mb-1"></i>
#         <span>Ransom Notes</span>
#       </a>
#     </li>
#     <li class="nav-item">
#       <a class="nav-link text-dark d-flex flex-column align-items-center justify-content-center text-center" href="/yara">
#         <i class="fa-solid fa-flask fs-4 mb-1"></i>
#         <span>YARA Rules</span>
#       </a>
#     </li>
#     <li class="nav-item">
#       <a class="nav-link text-dark d-flex flex-column align-items-center justify-content-center text-center" href="/ttps">
#         <i class="fa-solid fa-network-wired fs-4 mb-1"></i>
#         <span>TTPs Matrix</span>
#       </a>
#     </li>
#     <li class="nav-item">
#       <a class="nav-link text-dark d-flex flex-column align-items-center justify-content-center text-center" href="/ioc">
#         <i class="fa-solid fa-puzzle-piece fs-4 mb-1"></i>
#         <span>IoC</span>
#       </a>
#     </li>
#     <li class="nav-item">
#       <a class="nav-link text-dark d-flex flex-column align-items-center justify-content-center text-center" href="/notification">
#         <i class="fas fa-bell fs-4 mb-1"></i>
#         <span>Notifications</span>
#       </a>
#     </li>
#     <li class="nav-item">
#       <a class="nav-link text-dark d-flex flex-column align-items-center justify-content-center text-center" href="/api">
#         <i class="fa-solid fa-screwdriver-wrench fs-4 mb-1"></i>
#         <span>API</span>
#       </a>
#     </li>
#     <li class="nav-item mx-3"></li>
#     <li class="nav-item">
#       <button id="theme-toggle"
#               class="btn btn-link text-dark d-flex flex-column align-items-center justify-content-center text-center p-0 m-0"
#               style="text-decoration: none;font-size: 1.5rem;"
#               title="Toggle Theme">
#         <i id="theme-toggle-icon" class="fa-solid fs-4 mb-1"></i>
#         <span style="font-size: 0.95em;">&nbsp;</span>
#       </button>
#     </li>
#   </ul>
# </div>
#
#
#     </div>
#
#   </div>
# </nav>
#
# <!-- Toggle Script for Mobile Menu -->
# <script>
#   document.getElementById('menuToggle').addEventListener('click', function () {
#     const menu = document.getElementById('mobileMenu');
#     menu.style.display = (menu.style.display === 'none' || !menu.style.display) ? 'block' : 'none';
#   });
# </script>
#
#
# <div class="d-none d-lg-flex justify-content-end w-100 pe-3">
#   <a class="nav-link d-inline-flex align-items-center"
#      href="https://buymeacoffee.com/ransomwarelive"
#      target="_blank"
#      style="font-weight: 500;">
#     <i class="fa-solid fa-mug-hot me-2" style="color: #3CB371;"></i>Buy Me a Coffee
#   </a>
# </div>
#
#
#
# <!-- Expired: 2025-12-31 -->
#  <p></p>
#  <div class="bg-body-secondary text-body text-center py-2 px-3 mb-3 rounded shadow-sm">
#     <p class="mb-0 small">
#       Sponsored by <strong>Hudson Rock</strong> –
#       <a href="https://hudsonrock.com/free-tools/?=ransomwarelive" class="text-decoration-underline text-reset" target="_blank">
#         Use Hudson Rock's free cybercrime intelligence tools to learn how Infostealer infections are impacting your business
#       </a>
#       <i class="fa fa-external-link ms-1" aria-hidden="true"></i>
#     </p>
#   </div>
#
#
#       <div class="container-fluid px-lg-5 my-3">
#
# <h2></h2>
#
#
# <div class="container py-4">
#   <div class="row text-center">
#     <div class="col-6 col-md-3 mb-4">
#       <div class="p-3 border rounded shadow-sm">
#         <p class="mb-1">
#           <i class="fa-solid fa-people-roof fa-2x mb-2"></i><br />
#           <strong>Groups</strong>
#         </p>
#         <div class="counter fs-4 text-success" id="groupsCounter">0</div>
#       </div>
#     </div>
#     <div class="col-6 col-md-3 mb-4">
#       <div class="p-3 border rounded shadow-sm">
#         <p class="mb-1">
#           <i class="fa-solid fa-bullseye fa-2x mb-2"></i><br />
#           <strong>Victims</strong>
#         </p>
#         <div class="counter fs-4 text-danger" id="victimsCounter">0</div>
#       </div>
#     </div>
#     <div class="col-6 col-md-3 mb-4">
#       <div class="p-3 border rounded shadow-sm">
#         <p class="mb-1">
#           <i class="fa-regular fa-calendar-days fa-2x mb-2"></i><br />
#           <strong>This year</strong>
#         </p>
#         <div class="counter fs-4 text-warning" id="victimsThisYearCounter">0</div>
#       </div>
#     </div>
#     <div class="col-6 col-md-3 mb-4">
#       <div class="p-3 border rounded shadow-sm">
#         <p class="mb-1">
#           <i class="fa-regular fa-calendar-days fa-2x mb-2"></i><br />
#           <strong>This month</strong>
#         </p>
#         <div class="counter fs-4 text-success" id="victimsThisMonthCounter">0</div>
#       </div>
#     </div>
#   </div>
# </div>
#
# <script>
#   function animateCounter(id, start, end, duration) {
#     const element = document.getElementById(id);
#     let startTime = null;
#
#     const step = (timestamp) => {
#       if (!startTime) startTime = timestamp;
#       const progress = timestamp - startTime;
#       const current = Math.min(Math.floor(progress / duration * (end - start) + start), end);
#       element.textContent = current.toLocaleString();
#       if (progress < duration) {
#         requestAnimationFrame(step);
#       }
#     };
#
#     requestAnimationFrame(step);
#   }
#
#   animateCounter('groupsCounter', 0, 295, 2000);
#   animateCounter('victimsCounter', 0, 22613, 2000);
#   animateCounter('victimsThisMonthCounter', 0, 409, 2000);
#   animateCounter('victimsThisYearCounter', 0, 6126, 2000);
# </script>
#
#
#
# <div class="p-3 mb-4 rounded" style="border: 1px solid #155724; background-color: #d4edda;">
#   <p class="mb-1 text-success">
#     This page displays the <strong>100 most recent victim</strong> disclosures attributed to ransomware groups, as detected by <span class="badge bg-success text-white">Ransomware.live</span>. Our platform continuously monitors and scrapes ransomware group leak sites to identify and list newly published victims.
#   </p>
# </div>
#
#
#
#
#
#
#
#
#
#
# <!-- Legend Modal -->
# <div class="modal fade" id="legendModal" tabindex="-1" aria-labelledby="legendModalLabel" aria-hidden="true">
#     <div class="modal-dialog modal-lg modal-dialog-scrollable">
#       <div class="modal-content">
#         <div class="modal-header">
#           <h5 class="modal-title" id="legendModalLabel">Legend</h5>
#           <button type="button" class="btn-close" data-bs-dismiss="modal" aria-label="Close"></button>
#         </div>
#         <div class="modal-body">
#           <h6 class="text-muted">General Icons</h6>
#           <ul class="list-unstyled">
#             <li><i class="fas fa-camera text-success me-2"></i> <strong>Screenshot available</strong></li>
#             <li><i class="fas fa-globe-americas text-success me-2"></i> <strong>Company website</strong></li>
#             <li><i class="fas fa-user-secret text-success me-2"></i> <strong>Infostealer data found</strong></li>
#             <li><i class="fa-solid fa-pen-to-square text-danger me-2"></i> <strong>Victim has denied</strong></li>
#             <li><i class="fa-solid fa-dollar-sign text-success me-2"></i> <strong>Ransom amount known</strong></li>
#             <li><i class="fa-solid fa-database text-success me-2"></i> <strong>Leak size known</strong></li>
#             <li><i class="fa-solid fa-copy text-success me-2"></i> <strong>Duplicate claim detected</strong></li>
#             <li><i class="fa-solid fa-newspaper text-success me-2"></i> <strong>Press coverage of the cyberattack</strong></li>
#           </ul>
#
#
#           <hr>
#
#           <h6 class="text-muted">Sector Icons</h6>
#           <div class="row row-cols-1 row-cols-sm-2 row-cols-md-3">
#
#
#             <div class="col mb-2 d-flex align-items-center">
#               <i class="fas fa-industry me-2 text-success" style="width: 1.5rem;"></i>
#               <span>Manufacturing</span>
#             </div>
#
#             <div class="col mb-2 d-flex align-items-center">
#               <i class="fas fa-hard-hat me-2 text-success" style="width: 1.5rem;"></i>
#               <span>Construction</span>
#             </div>
#
#             <div class="col mb-2 d-flex align-items-center">
#               <i class="fas fa-truck-moving me-2 text-success" style="width: 1.5rem;"></i>
#               <span>Transportation/Logistics</span>
#             </div>
#
#             <div class="col mb-2 d-flex align-items-center">
#               <i class="fas fa-microchip me-2 text-success" style="width: 1.5rem;"></i>
#               <span>Technology</span>
#             </div>
#
#             <div class="col mb-2 d-flex align-items-center">
#               <i class="fas fa-notes-medical me-2 text-success" style="width: 1.5rem;"></i>
#               <span>Healthcare</span>
#             </div>
#
#             <div class="col mb-2 d-flex align-items-center">
#               <i class="fas fa-university me-2 text-success" style="width: 1.5rem;"></i>
#               <span>Financial Services</span>
#             </div>
#
#             <div class="col mb-2 d-flex align-items-center">
#               <i class="fas fa-landmark me-2 text-success" style="width: 1.5rem;"></i>
#               <span>Public Sector</span>
#             </div>
#
#             <div class="col mb-2 d-flex align-items-center">
#               <i class="fas fa-graduation-cap me-2 text-success" style="width: 1.5rem;"></i>
#               <span>Education</span>
#             </div>
#
#             <div class="col mb-2 d-flex align-items-center">
#               <i class="fas fa-briefcase me-2 text-success" style="width: 1.5rem;"></i>
#               <span>Business Services</span>
#             </div>
#
#             <div class="col mb-2 d-flex align-items-center">
#               <i class="fas fa-users me-2 text-success" style="width: 1.5rem;"></i>
#               <span>Consumer Services</span>
#             </div>
#
#             <div class="col mb-2 d-flex align-items-center">
#               <i class="fas fa-bolt me-2 text-success" style="width: 1.5rem;"></i>
#               <span>Energy</span>
#             </div>
#
#             <div class="col mb-2 d-flex align-items-center">
#               <i class="fas fa-signal me-2 text-success" style="width: 1.5rem;"></i>
#               <span>Telecommunication</span>
#             </div>
#
#             <div class="col mb-2 d-flex align-items-center">
#               <i class="fas fa-seedling me-2 text-success" style="width: 1.5rem;"></i>
#               <span>Agriculture and Food Production</span>
#             </div>
#
#             <div class="col mb-2 d-flex align-items-center">
#               <i class="fas fa-bed me-2 text-success" style="width: 1.5rem;"></i>
#               <span>Hospitality and Tourism</span>
#             </div>
#
#             <div class="col mb-2 d-flex align-items-center">
#               <i class="fas fa-question-circle me-2 text-success" style="width: 1.5rem;"></i>
#               <span>Not Found</span>
#             </div>
#
#           </div>
#         </div>
#       </div>
#     </div>
#   </div>
#
# <input type="text" class="form-control mb-3" id="search" placeholder="Search victims..." />
#
# <div class="row" id="victim-list">
#
#
#     <div class="col-12 col-sm-6 col-md-6 col-xxl-4 mb-4 victim-item">
#
#   <div class="list-group-item position-relative rounded-3" style="border: 2px solid lightgrey; box-shadow: 0 4px 8px rgba(0, 0, 0, 0.05); transition: all 0.3s ease;">
#     <div class="d-flex align-items-center"> <!-- Use flex to center the logo -->
#       <!-- Logo -->
#       <img src="
#             https://img.logo.dev/northstonington.k12.ct.us?token=pk_Txj9HAt5QTuMD0SLJCKIrQ&format=png&retina=true&fallback=404
#           "
#      onerror="this.onerror=null;this.src='data:image/svg+xml;utf8,<svg xmlns=&quot;http://www.w3.org/2000/svg&quot; width=&quot;60&quot; height=&quot;60&quot;></svg>'"
#      alt="Logo"
#      loading="lazy"
#      class="me-4 ms-3 flex-shrink-0"
#      style="width: 60px; height: 60px; object-fit: contain;" />
#
#       <!-- Content -->
#       <div class="d-flex flex-column text-start flex-grow-1">
#
#         <a href="/id/VGhlIE5vcnRoIFN0b25pbmd0b24gU2Nob29sIERpc3RyaWN0QGludGVybG9jaw==" class="text-body-emphasis text-decoration-none">
#           <strong>The North Stonington School District</strong>
#         </a>
#         <small>
#           <a href="/group/interlock">
#             <span class="badge bg-success">Interlock</span>
#           </a>
#         </small>
#
#         <div class="text-body-secondary mt-2" style="font-size: 0.85rem;">
#           <i class="fa-solid fa-calendar-days"></i> <strong>Discovery Date:</strong> 2025-10-15
#
#         </div>
#
#
#         <div class="mt-2">
#           <div class="p-2 rounded shadow-sm text-body-secondary bg-body-secondary" style="font-size: 0.85rem; max-width: 90%;">
#             North Stonington Public Schools have two public schools and 736 students, strives to create a safe e...
#           </div>
#         </div>
#
#
# <div class="mt-1">
#   <!-- Website -->
#
#     <a href="https://northstonington.k12.ct.us" target="_blank" rel="nofollow noopener noreferrer">
#       <i class="fas fa-globe-americas text-success" title="Website available"></i></a>
#
#
#   <!-- Infostealer -->
#
#     <a href="/id/VGhlIE5vcnRoIFN0b25pbmd0b24gU2Nob29sIERpc3RyaWN0QGludGVybG9jaw==#infostealer">
#       <i class="fas fa-user-secret text-success ms-2" title="Infostealer info available"></i></a>
#
#
#   <!-- Screenshot (post_url) -->
#
#     <a href="/id/VGhlIE5vcnRoIFN0b25pbmd0b24gU2Nob29sIERpc3RyaWN0QGludGVybG9jaw==#screenshot">
#       <i class="fas fa-camera text-success ms-2" title="Leak post available"></i></a>
#
#
#   <!-- Ransom info -->
#
#     <i class="fa-solid fa-dollar-sign text-muted-light ms-2" title="No ransom info"></i>
#
#   <!-- Ransom info -->
#
#     <i class="fa-solid fa-database text-muted-light ms-2" title="No leak data info"></i>
#
#   <!-- duplicate info -->
#    <!-- DEBUG: has_duplicate=True domain=northstonington.k12.ct.us -->
#
#     <a href="/search?q=northstonington.k12.ct.us&scope=website"><i class="fa-solid fa-copy text-success ms-2" title="Duplicate claims for The North Stonington School District"></i></a>
#
#   <!-- press info -->
#
#     <i class="fa-solid fa-newspaper text-muted-light ms-2" title="No press coveraged detected"></i>
#
#
#   <!-- Updates -->
#
#     <i class="fa-solid fa-pen-to-square text-muted-light ms-2" title="No update info"></i>
#
# </div>
#
#       </div>
#     </div>
#
#
#       <a href="/map/US"><img src="https://images.ransomware.live/flags/US.svg"
#            onerror="this.onerror=null;this.src='https://images.ransomware.live/none.png';"
#            alt="US"
#            class="position-absolute top-0 end-0 m-2"
#            style="width: 32px; height: 20px; object-fit: contain;" /></a>
#
#
#
#
#
#
#
#   <a href="/activity/Education"
#      title="View more victims in Education"
#      style="position: absolute; bottom: 0.5rem; right: 0.5rem;">
#     <i class="fas fa-graduation-cap text-success"
#        style="font-size: 1.5rem;"></i>
#   </a>
#
#   </div>
# </div>
#
#
#
#     <div class="col-12 col-sm-6 col-md-6 col-xxl-4 mb-4 victim-item">
#
#   <div class="list-group-item position-relative rounded-3" style="border: 2px solid lightgrey; box-shadow: 0 4px 8px rgba(0, 0, 0, 0.05); transition: all 0.3s ease;">
#     <div class="d-flex align-items-center"> <!-- Use flex to center the logo -->
#       <!-- Logo -->
#       <img src="
#             https://img.logo.dev/nbs-us.com?token=pk_Txj9HAt5QTuMD0SLJCKIrQ&format=png&retina=true&fallback=404
#           "
#      onerror="this.onerror=null;this.src='data:image/svg+xml;utf8,<svg xmlns=&quot;http://www.w3.org/2000/svg&quot; width=&quot;60&quot; height=&quot;60&quot;></svg>'"
#      alt="Logo"
#      loading="lazy"
#      class="me-4 ms-3 flex-shrink-0"
#      style="width: 60px; height: 60px; object-fit: contain;" />
#
#       <!-- Content -->
#       <div class="d-flex flex-column text-start flex-grow-1">
#
#         <a href="/id/TmF2aWdhdG9yIEJ1c2luZXNzIFNvbHV0aW9uc0BwZWFy" class="text-body-emphasis text-decoration-none">
#           <strong>Navigator Business Solutions</strong>
#         </a>
#         <small>
#           <a href="/group/pear">
#             <span class="badge bg-success">Pear</span>
#           </a>
#         </small>
#
#         <div class="text-body-secondary mt-2" style="font-size: 0.85rem;">
#           <i class="fa-solid fa-calendar-days"></i> <strong>Discovery Date:</strong> 2025-10-15
#
#             <br><i class="fa-solid fa-triangle-exclamation text-warning"></i> <strong>Estimated Attack Date:</strong> 2025-10-02
#
#         </div>
#
#
#         <div class="mt-2">
#           <div class="p-2 rounded shadow-sm text-body-secondary bg-body-secondary" style="font-size: 0.85rem; max-width: 90%;">
#             Helps companies conquer their industry and business complexity by implementing and supporting the be...
#           </div>
#         </div>
#
#
# <div class="mt-1">
#   <!-- Website -->
#
#     <a href="https://nbs-us.com" target="_blank" rel="nofollow noopener noreferrer">
#       <i class="fas fa-globe-americas text-success" title="Website available"></i></a>
#
#
#   <!-- Infostealer -->
#
#     <a href="/id/TmF2aWdhdG9yIEJ1c2luZXNzIFNvbHV0aW9uc0BwZWFy#infostealer">
#       <i class="fas fa-user-secret text-success ms-2" title="Infostealer info available"></i></a>
#
#
#   <!-- Screenshot (post_url) -->
#
#     <a href="/id/TmF2aWdhdG9yIEJ1c2luZXNzIFNvbHV0aW9uc0BwZWFy#screenshot">
#       <i class="fas fa-camera text-success ms-2" title="Leak post available"></i></a>
#
#
#   <!-- Ransom info -->
#
#     <i class="fa-solid fa-dollar-sign text-muted-light ms-2" title="No ransom info"></i>
#
#   <!-- Ransom info -->
#
#     <i class="fa-solid fa-database text-muted-light ms-2" title="No leak data info"></i>
#
#   <!-- duplicate info -->
#    <!-- DEBUG: has_duplicate=False domain=nbs-us.com -->
#
#     <i class="fa-solid fa-copy  text-muted-light ms-2" title="No other claim"></i>
#
#   <!-- press info -->
#
#     <i class="fa-solid fa-newspaper text-muted-light ms-2" title="No press coveraged detected"></i>
#
#
#   <!-- Updates -->
#
#     <i class="fa-solid fa-pen-to-square text-muted-light ms-2" title="No update info"></i>
#
# </div>
#
#       </div>
#     </div>
#
#
#       <a href="/map/US"><img src="https://images.ransomware.live/flags/US.svg"
#            onerror="this.onerror=null;this.src='https://images.ransomware.live/none.png';"
#            alt="US"
#            class="position-absolute top-0 end-0 m-2"
#            style="width: 32px; height: 20px; object-fit: contain;" /></a>
#
#
#
#
#
#
#
#   <a href="/activity/Technology"
#      title="View more victims in Technology"
#      style="position: absolute; bottom: 0.5rem; right: 0.5rem;">
#     <i class="fas fa-microchip text-success"
#        style="font-size: 1.5rem;"></i>
#   </a>
#
#   </div>
# </div>
#
#
#
#     <div class="col-12 col-sm-6 col-md-6 col-xxl-4 mb-4 victim-item">
#
#   <div class="list-group-item position-relative rounded-3" style="border: 2px solid lightgrey; box-shadow: 0 4px 8px rgba(0, 0, 0, 0.05); transition: all 0.3s ease;">
#     <div class="d-flex align-items-center"> <!-- Use flex to center the logo -->
#       <!-- Logo -->
#       <img src="
#             data:image/svg+xml;utf8,<svg xmlns='http://www.w3.org/2000/svg' width='60' height='60'></svg>
#           "
#      onerror="this.onerror=null;this.src='data:image/svg+xml;utf8,<svg xmlns=&quot;http://www.w3.org/2000/svg&quot; width=&quot;60&quot; height=&quot;60&quot;></svg>'"
#      alt="Logo"
#      loading="lazy"
#      class="me-4 ms-3 flex-shrink-0"
#      style="width: 60px; height: 60px; object-fit: contain;" />
#
#       <!-- Content -->
#       <div class="d-flex flex-column text-start flex-grow-1">
#
#         <a href="/id/VW5pbWVkIGRvIEJyYXNpbEBzYXJjb21h" class="text-body-emphasis text-decoration-none">
#           <strong>Unimed do Brasil</strong>
#         </a>
#         <small>
#           <a href="/group/sarcoma">
#             <span class="badge bg-success">Sarcoma</span>
#           </a>
#         </small>
#
#         <div class="text-body-secondary mt-2" style="font-size: 0.85rem;">
#           <i class="fa-solid fa-calendar-days"></i> <strong>Discovery Date:</strong> 2025-10-15
#
#         </div>
#
#
#         <div class="mt-2">
#           <div class="p-2 rounded shadow-sm text-body-secondary bg-body-secondary" style="font-size: 0.85rem; max-width: 90%;">
#             Unimed do Brasil
# Unimed Pelotas is a comprehensive health service center located in Pelotas, Brazil,...
#           </div>
#         </div>
#
#
# <div class="mt-1">
#   <!-- Website -->
#
#     <i class="fas fa-globe-americas text-muted-light" title="No website info"></i>
#
#
#   <!-- Infostealer -->
#
#     <i class="fas fa-user-secret text-muted-light ms-2" title="No infostealer info"></i>
#
#
#   <!-- Screenshot (post_url) -->
#
#     <i class="fas fa-camera text-muted-light ms-2" title="No leak post"></i>
#
#
#   <!-- Ransom info -->
#
#     <i class="fa-solid fa-dollar-sign text-muted-light ms-2" title="No ransom info"></i>
#
#   <!-- Ransom info -->
#
#     <i class="fa-solid fa-database text-muted-light ms-2" title="No leak data info"></i>
#
#   <!-- duplicate info -->
#    <!-- DEBUG: has_duplicate=False domain= -->
#
#     <i class="fa-solid fa-copy  text-muted-light ms-2" title="No other claim"></i>
#
#   <!-- press info -->
#
#     <i class="fa-solid fa-newspaper text-muted-light ms-2" title="No press coveraged detected"></i>
#
#
#   <!-- Updates -->
#
#     <i class="fa-solid fa-pen-to-square text-muted-light ms-2" title="No update info"></i>
#
# </div>
#
#       </div>
#     </div>
#
#
#       <a href="/map/BR"><img src="https://images.ransomware.live/flags/BR.svg"
#            onerror="this.onerror=null;this.src='https://images.ransomware.live/none.png';"
#            alt="BR"
#            class="position-absolute top-0 end-0 m-2"
#            style="width: 32px; height: 20px; object-fit: contain;" /></a>
#
#
#
#
#
#
#
#   <a href="/activity/Healthcare"
#      title="View more victims in Healthcare"
#      style="position: absolute; bottom: 0.5rem; right: 0.5rem;">
#     <i class="fas fa-notes-medical text-success"
#        style="font-size: 1.5rem;"></i>
#   </a>
#
#   </div>
# </div>
#
#
#
#     <div class="col-12 col-sm-6 col-md-6 col-xxl-4 mb-4 victim-item">
#
#   <div class="list-group-item position-relative rounded-3" style="border: 2px solid lightgrey; box-shadow: 0 4px 8px rgba(0, 0, 0, 0.05); transition: all 0.3s ease;">
#     <div class="d-flex align-items-center"> <!-- Use flex to center the logo -->
#       <!-- Logo -->
#       <img src="
#             https://img.logo.dev/www.alltruck.com?token=pk_Txj9HAt5QTuMD0SLJCKIrQ&format=png&retina=true&fallback=404
#           "
#      onerror="this.onerror=null;this.src='data:image/svg+xml;utf8,<svg xmlns=&quot;http://www.w3.org/2000/svg&quot; width=&quot;60&quot; height=&quot;60&quot;></svg>'"
#      alt="Logo"
#      loading="lazy"
#      class="me-4 ms-3 flex-shrink-0"
#      style="width: 60px; height: 60px; object-fit: contain;" />
#
#       <!-- Content -->
#       <div class="d-flex flex-column text-start flex-grow-1">
#
#         <a href="/id/QWxsIFRydWNrIFRyYW5zcG9ydGF0aW9uIENvLiwgSW5jLkBxaWxpbg==" class="text-body-emphasis text-decoration-none">
#           <strong>All Truck Transportation Co., Inc.</strong>
#         </a>
#         <small>
#           <a href="/group/qilin">
#             <span class="badge bg-success">Qilin</span>
#           </a>
#         </small>
#
#         <div class="text-body-secondary mt-2" style="font-size: 0.85rem;">
#           <i class="fa-solid fa-calendar-days"></i> <strong>Discovery Date:</strong> 2025-10-15
#
#             <br><i class="fa-solid fa-triangle-exclamation text-warning"></i> <strong>Estimated Attack Date:</strong> 2025-08-19
#
#         </div>
#
#
#         <div class="mt-2">
#           <div class="p-2 rounded shadow-sm text-body-secondary bg-body-secondary" style="font-size: 0.85rem; max-width: 90%;">
#             All Truck Transportation Co., Inc. is an asset-based carrier offering local and regional truckload t...
#           </div>
#         </div>
#
#
# <div class="mt-1">
#   <!-- Website -->
#
#     <a href="https://www.alltruck.com" target="_blank" rel="nofollow noopener noreferrer">
#       <i class="fas fa-globe-americas text-success" title="Website available"></i></a>
#
#
#   <!-- Infostealer -->
#
#     <i class="fas fa-user-secret text-muted-light ms-2" title="No infostealer info"></i>
#
#
#   <!-- Screenshot (post_url) -->
#
#     <a href="/id/QWxsIFRydWNrIFRyYW5zcG9ydGF0aW9uIENvLiwgSW5jLkBxaWxpbg==#screenshot">
#       <i class="fas fa-camera text-success ms-2" title="Leak post available"></i></a>
#
#
#   <!-- Ransom info -->
#
#     <i class="fa-solid fa-dollar-sign text-muted-light ms-2" title="No ransom info"></i>
#
#   <!-- Ransom info -->
#
#     <i class="fa-solid fa-database text-muted-light ms-2" title="No leak data info"></i>
#
#   <!-- duplicate info -->
#    <!-- DEBUG: has_duplicate=True domain=www.alltruck.com -->
#
#     <a href="/search?q=alltruck.com&scope=website"><i class="fa-solid fa-copy text-success ms-2" title="Duplicate claims for All Truck Transportation Co., Inc."></i></a>
#
#   <!-- press info -->
#
#     <i class="fa-solid fa-newspaper text-muted-light ms-2" title="No press coveraged detected"></i>
#
#
#   <!-- Updates -->
#
#     <i class="fa-solid fa-pen-to-square text-muted-light ms-2" title="No update info"></i>
#
# </div>
#
#       </div>
#     </div>
#
#
#       <a href="/map/US"><img src="https://images.ransomware.live/flags/US.svg"
#            onerror="this.onerror=null;this.src='https://images.ransomware.live/none.png';"
#            alt="US"
#            class="position-absolute top-0 end-0 m-2"
#            style="width: 32px; height: 20px; object-fit: contain;" /></a>
#
#
#
#
#
#
#
#   <a href="/activity/Transportation-Logistics"
#      title="View more victims in Transportation/Logistics"
#      style="position: absolute; bottom: 0.5rem; right: 0.5rem;">
#     <i class="fas fa-truck-moving text-success"
#        style="font-size: 1.5rem;"></i>
#   </a>
#
#   </div>
# </div>
#
#
#
#     <div class="col-12 col-sm-6 col-md-6 col-xxl-4 mb-4 victim-item">
#
#   <div class="list-group-item position-relative rounded-3" style="border: 2px solid lightgrey; box-shadow: 0 4px 8px rgba(0, 0, 0, 0.05); transition: all 0.3s ease;">
#     <div class="d-flex align-items-center"> <!-- Use flex to center the logo -->
#       <!-- Logo -->
#       <img src="
#             https://img.logo.dev/charlesriver.properties?token=pk_Txj9HAt5QTuMD0SLJCKIrQ&format=png&retina=true&fallback=404
#           "
#      onerror="this.onerror=null;this.src='data:image/svg+xml;utf8,<svg xmlns=&quot;http://www.w3.org/2000/svg&quot; width=&quot;60&quot; height=&quot;60&quot;></svg>'"
#      alt="Logo"
#      loading="lazy"
#      class="me-4 ms-3 flex-shrink-0"
#      style="width: 60px; height: 60px; object-fit: contain;" />
#
#       <!-- Content -->
#       <div class="d-flex flex-column text-start flex-grow-1">
#
#         <a href="/id/Q2hhcmxlcyBSaXZlciBQcm9wZXJ0aWVzQHFpbGlu" class="text-body-emphasis text-decoration-none">
#           <strong>Charles River Properties</strong>
#         </a>
#         <small>
#           <a href="/group/qilin">
#             <span class="badge bg-success">Qilin</span>
#           </a>
#         </small>
#
#         <div class="text-body-secondary mt-2" style="font-size: 0.85rem;">
#           <i class="fa-solid fa-calendar-days"></i> <strong>Discovery Date:</strong> 2025-10-15
#
#             <br><i class="fa-solid fa-triangle-exclamation text-warning"></i> <strong>Estimated Attack Date:</strong> 2025-10-14
#
#         </div>
#
#
#         <div class="mt-2">
#           <div class="p-2 rounded shadow-sm text-body-secondary bg-body-secondary" style="font-size: 0.85rem; max-width: 90%;">
#             Charles River Properties, USA -  a real estate brokerage based in Waltham, Massachusetts, that handl...
#           </div>
#         </div>
#
#
# <div class="mt-1">
#   <!-- Website -->
#
#     <a href="https://charlesriver.properties" target="_blank" rel="nofollow noopener noreferrer">
#       <i class="fas fa-globe-americas text-success" title="Website available"></i></a>
#
#
#   <!-- Infostealer -->
#
#     <i class="fas fa-user-secret text-muted-light ms-2" title="No infostealer info"></i>
#
#
#   <!-- Screenshot (post_url) -->
#
#     <a href="/id/Q2hhcmxlcyBSaXZlciBQcm9wZXJ0aWVzQHFpbGlu#screenshot">
#       <i class="fas fa-camera text-success ms-2" title="Leak post available"></i></a>
#
#
#   <!-- Ransom info -->
#
#     <i class="fa-solid fa-dollar-sign text-muted-light ms-2" title="No ransom info"></i>
#
#   <!-- Ransom info -->
#
#     <i class="fa-solid fa-database text-muted-light ms-2" title="No leak data info"></i>
#
#   <!-- duplicate info -->
#    <!-- DEBUG: has_duplicate=False domain=charlesriver.properties -->
#
#     <i class="fa-solid fa-copy  text-muted-light ms-2" title="No other claim"></i>
#
#   <!-- press info -->
#
#     <i class="fa-solid fa-newspaper text-muted-light ms-2" title="No press coveraged detected"></i>
#
#
#   <!-- Updates -->
#
#     <i class="fa-solid fa-pen-to-square text-muted-light ms-2" title="No update info"></i>
#
# </div>
#
#       </div>
#     </div>
#
#
#       <a href="/map/US"><img src="https://images.ransomware.live/flags/US.svg"
#            onerror="this.onerror=null;this.src='https://images.ransomware.live/none.png';"
#            alt="US"
#            class="position-absolute top-0 end-0 m-2"
#            style="width: 32px; height: 20px; object-fit: contain;" /></a>
#
#
#
#
#
#
#
#   <i class="fas fa-question-circle text-muted-light"
#      title="Not Found"
#      style="position: absolute; bottom: 0.5rem; right: 0.5rem; font-size: 1.5rem;"></i>
#
#   </div>
# </div>
#
#
#
#     <div class="col-12 col-sm-6 col-md-6 col-xxl-4 mb-4 victim-item">
#
#   <div class="list-group-item position-relative rounded-3" style="border: 2px solid lightgrey; box-shadow: 0 4px 8px rgba(0, 0, 0, 0.05); transition: all 0.3s ease;">
#     <div class="d-flex align-items-center"> <!-- Use flex to center the logo -->
#       <!-- Logo -->
#       <img src="
#             https://img.logo.dev/www.icetstudios.com?token=pk_Txj9HAt5QTuMD0SLJCKIrQ&format=png&retina=true&fallback=404
#           "
#      onerror="this.onerror=null;this.src='data:image/svg+xml;utf8,<svg xmlns=&quot;http://www.w3.org/2000/svg&quot; width=&quot;60&quot; height=&quot;60&quot;></svg>'"
#      alt="Logo"
#      loading="lazy"
#      class="me-4 ms-3 flex-shrink-0"
#      style="width: 60px; height: 60px; object-fit: contain;" />
#
#       <!-- Content -->
#       <div class="d-flex flex-column text-start flex-grow-1">
#
#         <a href="/id/SUNFVCBTdHVkaW9zQHRoZWdlbnRsZW1lbg==" class="text-body-emphasis text-decoration-none">
#           <strong>ICET Studios</strong>
#         </a>
#         <small>
#           <a href="/group/thegentlemen">
#             <span class="badge bg-success">Thegentlemen</span>
#           </a>
#         </small>
#
#         <div class="text-body-secondary mt-2" style="font-size: 0.85rem;">
#           <i class="fa-solid fa-calendar-days"></i> <strong>Discovery Date:</strong> 2025-10-14
#
#         </div>
#
#
#         <div class="mt-2">
#           <div class="p-2 rounded shadow-sm text-body-secondary bg-body-secondary" style="font-size: 0.85rem; max-width: 90%;">
#             www.icetstudios.com All&#39;interno delle proprie strutture la ICET Studios dispone di personale qualifi...
#           </div>
#         </div>
#
#
# <div class="mt-1">
#   <!-- Website -->
#
#     <a href="https://www.icetstudios.com" target="_blank" rel="nofollow noopener noreferrer">
#       <i class="fas fa-globe-americas text-success" title="Website available"></i></a>
#
#
#   <!-- Infostealer -->
#
#     <i class="fas fa-user-secret text-muted-light ms-2" title="No infostealer info"></i>
#
#
#   <!-- Screenshot (post_url) -->
#
#     <a href="/id/SUNFVCBTdHVkaW9zQHRoZWdlbnRsZW1lbg==#screenshot">
#       <i class="fas fa-camera text-success ms-2" title="Leak post available"></i></a>
#
#
#   <!-- Ransom info -->
#
#     <i class="fa-solid fa-dollar-sign text-muted-light ms-2" title="No ransom info"></i>
#
#   <!-- Ransom info -->
#
#     <i class="fa-solid fa-database text-muted-light ms-2" title="No leak data info"></i>
#
#   <!-- duplicate info -->
#    <!-- DEBUG: has_duplicate=False domain=www.icetstudios.com -->
#
#     <i class="fa-solid fa-copy  text-muted-light ms-2" title="No other claim"></i>
#
#   <!-- press info -->
#
#     <i class="fa-solid fa-newspaper text-muted-light ms-2" title="No press coveraged detected"></i>
#
#
#   <!-- Updates -->
#
#     <i class="fa-solid fa-pen-to-square text-muted-light ms-2" title="No update info"></i>
#
# </div>
#
#       </div>
#     </div>
#
#
#
#
#
#
#
#
#   <i class="fas fa-question-circle text-muted-light"
#      title="Not Found"
#      style="position: absolute; bottom: 0.5rem; right: 0.5rem; font-size: 1.5rem;"></i>
#
#   </div>
# </div>
#
#
#
#     <div class="col-12 col-sm-6 col-md-6 col-xxl-4 mb-4 victim-item">
#
#   <div class="list-group-item position-relative rounded-3" style="border: 2px solid lightgrey; box-shadow: 0 4px 8px rgba(0, 0, 0, 0.05); transition: all 0.3s ease;">
#     <div class="d-flex align-items-center"> <!-- Use flex to center the logo -->
#       <!-- Logo -->
#       <img src="
#             https://img.logo.dev/www.landmarkmgtinc.com?token=pk_Txj9HAt5QTuMD0SLJCKIrQ&format=png&retina=true&fallback=404
#           "
#      onerror="this.onerror=null;this.src='data:image/svg+xml;utf8,<svg xmlns=&quot;http://www.w3.org/2000/svg&quot; width=&quot;60&quot; height=&quot;60&quot;></svg>'"
#      alt="Logo"
#      loading="lazy"
#      class="me-4 ms-3 flex-shrink-0"
#      style="width: 60px; height: 60px; object-fit: contain;" />
#
#       <!-- Content -->
#       <div class="d-flex flex-column text-start flex-grow-1">
#
#         <a href="/id/TGFuZG1hcmsgTWFuYWdlbWVudEBxaWxpbg==" class="text-body-emphasis text-decoration-none">
#           <strong>Landmark Management</strong>
#         </a>
#         <small>
#           <a href="/group/qilin">
#             <span class="badge bg-success">Qilin</span>
#           </a>
#         </small>
#
#         <div class="text-body-secondary mt-2" style="font-size: 0.85rem;">
#           <i class="fa-solid fa-calendar-days"></i> <strong>Discovery Date:</strong> 2025-10-14
#
#         </div>
#
#
#         <div class="mt-2">
#           <div class="p-2 rounded shadow-sm text-body-secondary bg-body-secondary" style="font-size: 0.85rem; max-width: 90%;">
#             Landmark Management, Inc., manages 90 projects, consisting of 2,462 units across 5 states. Whether y...
#           </div>
#         </div>
#
#
# <div class="mt-1">
#   <!-- Website -->
#
#     <a href="https://www.landmarkmgtinc.com" target="_blank" rel="nofollow noopener noreferrer">
#       <i class="fas fa-globe-americas text-success" title="Website available"></i></a>
#
#
#   <!-- Infostealer -->
#
#     <i class="fas fa-user-secret text-muted-light ms-2" title="No infostealer info"></i>
#
#
#   <!-- Screenshot (post_url) -->
#
#     <a href="/id/TGFuZG1hcmsgTWFuYWdlbWVudEBxaWxpbg==#screenshot">
#       <i class="fas fa-camera text-success ms-2" title="Leak post available"></i></a>
#
#
#   <!-- Ransom info -->
#
#     <i class="fa-solid fa-dollar-sign text-muted-light ms-2" title="No ransom info"></i>
#
#   <!-- Ransom info -->
#
#     <i class="fa-solid fa-database text-muted-light ms-2" title="No leak data info"></i>
#
#   <!-- duplicate info -->
#    <!-- DEBUG: has_duplicate=True domain=www.landmarkmgtinc.com -->
#
#     <a href="/search?q=landmarkmgtinc.com&scope=website"><i class="fa-solid fa-copy text-success ms-2" title="Duplicate claims for Landmark Management"></i></a>
#
#   <!-- press info -->
#
#     <i class="fa-solid fa-newspaper text-muted-light ms-2" title="No press coveraged detected"></i>
#
#
#   <!-- Updates -->
#
#     <i class="fa-solid fa-pen-to-square text-muted-light ms-2" title="No update info"></i>
#
# </div>
#
#       </div>
#     </div>
#
#
#
#
#
#
#
#
#   <i class="fas fa-question-circle text-muted-light"
#      title="Not Found"
#      style="position: absolute; bottom: 0.5rem; right: 0.5rem; font-size: 1.5rem;"></i>
#
#   </div>
# </div>
#
#
#
#     <div class="col-12 col-sm-6 col-md-6 col-xxl-4 mb-4 victim-item">
#
#   <div class="list-group-item position-relative rounded-3" style="border: 2px solid lightgrey; box-shadow: 0 4px 8px rgba(0, 0, 0, 0.05); transition: all 0.3s ease;">
#     <div class="d-flex align-items-center"> <!-- Use flex to center the logo -->
#       <!-- Logo -->
#       <img src="
#             https://img.logo.dev/www.njguaranty.org?token=pk_Txj9HAt5QTuMD0SLJCKIrQ&format=png&retina=true&fallback=404
#           "
#      onerror="this.onerror=null;this.src='data:image/svg+xml;utf8,<svg xmlns=&quot;http://www.w3.org/2000/svg&quot; width=&quot;60&quot; height=&quot;60&quot;></svg>'"
#      alt="Logo"
#      loading="lazy"
#      class="me-4 ms-3 flex-shrink-0"
#      style="width: 60px; height: 60px; object-fit: contain;" />
#
#       <!-- Content -->
#       <div class="d-flex flex-column text-start flex-grow-1">
#
#         <a href="/id/TmV3IEplcnNleSBQcm9wZXJ0eS1MaWFiaWxpdHkgSW5zdXJhbmNlIEd1YXJhbnR5IEFzc29jaWF0aW9uQHFpbGlu" class="text-body-emphasis text-decoration-none">
#           <strong>New Jersey Property-Liability Insurance Guaranty Association</strong>
#         </a>
#         <small>
#           <a href="/group/qilin">
#             <span class="badge bg-success">Qilin</span>
#           </a>
#         </small>
#
#         <div class="text-body-secondary mt-2" style="font-size: 0.85rem;">
#           <i class="fa-solid fa-calendar-days"></i> <strong>Discovery Date:</strong> 2025-10-14
#
#         </div>
#
#
#         <div class="mt-2">
#           <div class="p-2 rounded shadow-sm text-body-secondary bg-body-secondary" style="font-size: 0.85rem; max-width: 90%;">
# ...
#      style="position: absolute; bottom: 0.5rem; right: 0.5rem;">
#     <i class="fas fa-truck-moving text-success"
#        style="font-size: 1.5rem;"></i>
#   </a>
#
#   </div>
# </div>
#
#
#
#     <div class="col-12 col-sm-6 col-md-6 col-xxl-4 mb-4 victim-item">
#
#   <div class="list-group-item position-relative rounded-3" style="border: 2px solid lightgrey; box-shadow: 0 4px 8px rgba(0, 0, 0, 0.05); transition: all 0.3s ease;">
#     <div class="d-flex align-items-center"> <!-- Use flex to center the logo -->
#       <!-- Logo -->
#       <img src="
#             https://img.logo.dev/dsv.com?token=pk_Txj9HAt5QTuMD0SLJCKIrQ&format=png&retina=true&fallback=404
#           "
#      onerror="this.onerror=null;this.src='data:image/svg+xml;utf8,<svg xmlns=&quot;http://www.w3.org/2000/svg&quot; width=&quot;60&quot; height=&quot;60&quot;></svg>'"
#      alt="Logo"
#      loading="lazy"
#      class="me-4 ms-3 flex-shrink-0"
#      style="width: 60px; height: 60px; object-fit: contain;" />
#
#       <!-- Content -->
#       <div class="d-flex flex-column text-start flex-grow-1">
#
#         <a href="/id/ZHN2LmNvbUBjb2luYmFzZWNhcnRlbA==" class="text-body-emphasis text-decoration-none">
#           <strong>dsv.com</strong>
#         </a>
#         <small>
#           <a href="/group/coinbasecartel">
#             <span class="badge bg-success">Coinbasecartel</span>
#           </a>
#         </small>
#
#         <div class="text-body-secondary mt-2" style="font-size: 0.85rem;">
#           <i class="fa-solid fa-calendar-days"></i> <strong>Discovery Date:</strong> 2025-10-13
#
#         </div>
#
#
#         <div class="mt-2">
#           <div class="p-2 rounded shadow-sm text-body-secondary bg-body-secondary" style="font-size: 0.85rem; max-width: 90%;">
#             DSV is a global transport and logistics company that provides and manages supply chain solutions for...
#           </div>
#         </div>
#
#
# <div class="mt-1">
#   <!-- Website -->
#
#     <a href="https://dsv.com" target="_blank" rel="nofollow noopener noreferrer">
#       <i class="fas fa-globe-americas text-success" title="Website available"></i></a>
#
#
#   <!-- Infostealer -->
#
#     <a href="/id/ZHN2LmNvbUBjb2luYmFzZWNhcnRlbA==#infostealer">
#       <i class="fas fa-user-secret text-success ms-2" title="Infostealer info available"></i></a>
#
#
#   <!-- Screenshot (post_url) -->
#
#     <a href="/id/ZHN2LmNvbUBjb2luYmFzZWNhcnRlbA==#screenshot">
#       <i class="fas fa-camera text-success ms-2" title="Leak post available"></i></a>
#
#
#   <!-- Ransom info -->
#
#     <i class="fa-solid fa-dollar-sign text-muted-light ms-2" title="No ransom info"></i>
#
#   <!-- Ransom info -->
#
#     <i class="fa-solid fa-database text-muted-light ms-2" title="No leak data info"></i>
#
#   <!-- duplicate info -->
#    <!-- DEBUG: has_duplicate=False domain=dsv.com -->
#
#     <i class="fa-solid fa-copy  text-muted-light ms-2" title="No other claim"></i>
#
#   <!-- press info -->
#
#     <i class="fa-solid fa-newspaper text-muted-light ms-2" title="No press coveraged detected"></i>
#
#
#   <!-- Updates -->
#
#     <i class="fa-solid fa-pen-to-square text-muted-light ms-2" title="No update info"></i>
#
# </div>
#
#       </div>
#     </div>
#
#
#       <a href="/map/DK"><img src="https://images.ransomware.live/flags/DK.svg"
#            onerror="this.onerror=null;this.src='https://images.ransomware.live/none.png';"
#            alt="DK"
#            class="position-absolute top-0 end-0 m-2"
#            style="width: 32px; height: 20px; object-fit: contain;" /></a>
#
#
#
#
#
#
#
#   <a href="/activity/Transportation-Logistics"
#      title="View more victims in Transportation/Logistics"
#      style="position: absolute; bottom: 0.5rem; right: 0.5rem;">
#     <i class="fas fa-truck-moving text-success"
#        style="font-size: 1.5rem;"></i>
#   </a>
#
#   </div>
# </div>
#
#
#
#     <div class="col-12 col-sm-6 col-md-6 col-xxl-4 mb-4 victim-item">
#
#   <div class="list-group-item position-relative rounded-3" style="border: 2px solid lightgrey; box-shadow: 0 4px 8px rgba(0, 0, 0, 0.05); transition: all 0.3s ease;">
#     <div class="d-flex align-items-center"> <!-- Use flex to center the logo -->
#       <!-- Logo -->
#       <img src="
#             https://img.logo.dev/kuehne-nagel.com?token=pk_Txj9HAt5QTuMD0SLJCKIrQ&format=png&retina=true&fallback=404
#           "
#      onerror="this.onerror=null;this.src='data:image/svg+xml;utf8,<svg xmlns=&quot;http://www.w3.org/2000/svg&quot; width=&quot;60&quot; height=&quot;60&quot;></svg>'"
#      alt="Logo"
#      loading="lazy"
#      class="me-4 ms-3 flex-shrink-0"
#      style="width: 60px; height: 60px; object-fit: contain;" />
#
#       <!-- Content -->
#       <div class="d-flex flex-column text-start flex-grow-1">
#
#         <a href="/id/S3VlaG5lICsgTmFnZWxAY29pbmJhc2VjYXJ0ZWw=" class="text-body-emphasis text-decoration-none">
#           <strong>Kuehne + Nagel</strong>
#         </a>
#         <small>
#           <a href="/group/coinbasecartel">
#             <span class="badge bg-success">Coinbasecartel</span>
#           </a>
#         </small>
#
#         <div class="text-body-secondary mt-2" style="font-size: 0.85rem;">
#           <i class="fa-solid fa-calendar-days"></i> <strong>Discovery Date:</strong> 2025-10-13
#
#         </div>
#
#
#         <div class="mt-2">
#           <div class="p-2 rounded shadow-sm text-body-secondary bg-body-secondary" style="font-size: 0.85rem; max-width: 90%;">
#             With more than 82,000 employees at almost 1,300 sites in close to 100 countries, the Kuehne+Nagel Gr...
#           </div>
#         </div>
#
#
# <div class="mt-1">
#   <!-- Website -->
#
#     <a href="https://kuehne-nagel.com" target="_blank" rel="nofollow noopener noreferrer">
#       <i class="fas fa-globe-americas text-success" title="Website available"></i></a>
#
#
#   <!-- Infostealer -->
#
#     <a href="/id/S3VlaG5lICsgTmFnZWxAY29pbmJhc2VjYXJ0ZWw=#infostealer">
#       <i class="fas fa-user-secret text-success ms-2" title="Infostealer info available"></i></a>
#
#
#   <!-- Screenshot (post_url) -->
#
#     <a href="/id/S3VlaG5lICsgTmFnZWxAY29pbmJhc2VjYXJ0ZWw=#screenshot">
#       <i class="fas fa-camera text-success ms-2" title="Leak post available"></i></a>
#
#
#   <!-- Ransom info -->
#
#     <i class="fa-solid fa-dollar-sign text-muted-light ms-2" title="No ransom info"></i>
#
#   <!-- Ransom info -->
#
#     <i class="fa-solid fa-database text-muted-light ms-2" title="No leak data info"></i>
#
#   <!-- duplicate info -->
#    <!-- DEBUG: has_duplicate=False domain=kuehne-nagel.com -->
#
#     <i class="fa-solid fa-copy  text-muted-light ms-2" title="No other claim"></i>
#
#   <!-- press info -->
#
#     <i class="fa-solid fa-newspaper text-muted-light ms-2" title="No press coveraged detected"></i>
#
#
#   <!-- Updates -->
#
#     <i class="fa-solid fa-pen-to-square text-muted-light ms-2" title="No update info"></i>
#
# </div>
#
#       </div>
#     </div>
#
#
#       <a href="/map/CH"><img src="https://images.ransomware.live/flags/CH.svg"
#            onerror="this.onerror=null;this.src='https://images.ransomware.live/none.png';"
#            alt="CH"
#            class="position-absolute top-0 end-0 m-2"
#            style="width: 32px; height: 20px; object-fit: contain;" /></a>
#
#
#
#
#
#
#
#   <a href="/activity/Transportation-Logistics"
#      title="View more victims in Transportation/Logistics"
#      style="position: absolute; bottom: 0.5rem; right: 0.5rem;">
#     <i class="fas fa-truck-moving text-success"
#        style="font-size: 1.5rem;"></i>
#   </a>
#
#   </div>
# </div>
#
#
#
#     <div class="col-12 col-sm-6 col-md-6 col-xxl-4 mb-4 victim-item">
#
#   <div class="list-group-item position-relative rounded-3" style="border: 2px solid lightgrey; box-shadow: 0 4px 8px rgba(0, 0, 0, 0.05); transition: all 0.3s ease;">
#     <div class="d-flex align-items-center"> <!-- Use flex to center the logo -->
#       <!-- Logo -->
#       <img src="
#             data:image/svg+xml;utf8,<svg xmlns='http://www.w3.org/2000/svg' width='60' height='60'></svg>
#           "
#      onerror="this.onerror=null;this.src='data:image/svg+xml;utf8,<svg xmlns=&quot;http://www.w3.org/2000/svg&quot; width=&quot;60&quot; height=&quot;60&quot;></svg>'"
#      alt="Logo"
#      loading="lazy"
#      class="me-4 ms-3 flex-shrink-0"
#      style="width: 60px; height: 60px; object-fit: contain;" />
#
#       <!-- Content -->
#       <div class="d-flex flex-column text-start flex-grow-1">
#
#         <a href="/id/QWx0YXMgVGVtaXpsaWtAYmxhY2tzaHJhbnRhYw==" class="text-body-emphasis text-decoration-none">
#           <strong>Altas Temizlik</strong>
#         </a>
#         <small>
#           <a href="/group/blackshrantac">
#             <span class="badge bg-success">Blackshrantac</span>
#           </a>
#         </small>
#
#         <div class="text-body-secondary mt-2" style="font-size: 0.85rem;">
#           <i class="fa-solid fa-calendar-days"></i> <strong>Discovery Date:</strong> 2025-10-13
#
#         </div>
#
#
#         <div class="mt-2">
#           <div class="p-2 rounded shadow-sm text-body-secondary bg-body-secondary" style="font-size: 0.85rem; max-width: 90%;">
#             [AI generated] N/A...
#           </div>
#         </div>
#
#
# <div class="mt-1">
#   <!-- Website -->
#
#     <i class="fas fa-globe-americas text-muted-light" title="No website info"></i>
#
#
#   <!-- Infostealer -->
#
#     <i class="fas fa-user-secret text-muted-light ms-2" title="No infostealer info"></i>
#
#
#   <!-- Screenshot (post_url) -->
#
#     <a href="/id/QWx0YXMgVGVtaXpsaWtAYmxhY2tzaHJhbnRhYw==#screenshot">
#       <i class="fas fa-camera text-success ms-2" title="Leak post available"></i></a>
#
#
#   <!-- Ransom info -->
#
#     <i class="fa-solid fa-dollar-sign text-muted-light ms-2" title="No ransom info"></i>
#
#   <!-- Ransom info -->
#
#     <i class="fa-solid fa-database text-muted-light ms-2" title="No leak data info"></i>
#
#   <!-- duplicate info -->
#    <!-- DEBUG: has_duplicate=False domain= -->
#
#     <i class="fa-solid fa-copy  text-muted-light ms-2" title="No other claim"></i>
#
#   <!-- press info -->
#
#     <i class="fa-solid fa-newspaper text-muted-light ms-2" title="No press coveraged detected"></i>
#
#
#   <!-- Updates -->
#
#     <i class="fa-solid fa-pen-to-square text-muted-light ms-2" title="No update info"></i>
#
# </div>
#
#       </div>
#     </div>
#
#
#       <a href="/map/TR"><img src="https://images.ransomware.live/flags/TR.svg"
#            onerror="this.onerror=null;this.src='https://images.ransomware.live/none.png';"
#            alt="TR"
#            class="position-absolute top-0 end-0 m-2"
#            style="width: 32px; height: 20px; object-fit: contain;" /></a>
#
#
#
#
#
#
#
#   <i class="fas fa-question-circle text-muted-light"
#      title="Not Found"
#      style="position: absolute; bottom: 0.5rem; right: 0.5rem; font-size: 1.5rem;"></i>
#
#   </div>
# </div>
#
#
# </div>
#
#
# </div>
# <!-- Footer Section -->
# <footer class="bg-dark text-white py-4 mt-5 mt-auto">
#   <div class="container">
#     <div class="row">
#       <!-- Copyright and Contact Info -->
#       <div class="col-12 col-md-6 mb-3 mb-md-0">
#         <p class="mb-0">&copy; 2025 Ransomware.live. All rights reserved.</p>
#         <p class="mb-0">
#           <i class="fa-regular fa-envelope"></i>&nbsp;
#           <a href="https://ransomwarelive.freshdesk.com/support/tickets/new" target="_blank" class="text-white">Contact us</a>
#           &nbsp;|&nbsp;
#           <i class="fa-brands fa-bluesky"></i>&nbsp;
#           <a href="https://bsky.app/profile/ransomware.live" target="_blank" title="Follow us on BlueSky" class="text-white">BlueSky</a>
#           &nbsp;|&nbsp;
#           <i class="fab fa-github"></i>&nbsp;
#           <a href="https://github.com/jmousqueton/ransomware.live" target="_blank" title="Follow us on GitHub" class="text-white">GitHub</a>
#           &nbsp;|&nbsp;
#           <i class="fa-brands fa-linkedin"></i>&nbsp;
#           <a href="https://www.linkedin.com/company/ransomwarelive" target="_blank" title="Follow us on LinkedIn" class="text-white">LinkedIn</a>
#         </p>
#       </div>
#
#       <!-- Terms & Support -->
#       <div class="col-12 col-md-6 text-md-end mb-3 mb-md-0">
#         <p class="mb-0">
#           <i class="fa-solid fa-scale-balanced"></i>&nbsp;
#           <a href="/t&c" class="text-white">Terms & Conditions</a>
#         </p>
#         <p class="mb-0">
#           <i class="fa-solid fa-circle-exclamation"></i></i>&nbsp;
#           <a href="/disclaimer" class="text-white">Disclaimer</a>
#         </p>
#         <p class="mb-0">
#           <i style="color: red" class="fa-solid fa-heart"></i>&nbsp;
#           <a href="https://buymeacoffee.com/ransomwarelive" target="_blank" class="text-white">Support Ransomware.live</a>
#         </p>
#       </div>
#     </div>
#
#     <!-- Last Dataset Update and Logo Credits -->
#     <div class="row">
#       <div class="col-12 col-md-6">
#         <p class="note mb-0">Dataset update: 2025-10-15 11:53:53 UTC</p>
#         <p class="note mb-0">
#           Logos provided by <a href="https://logo.dev" alt="Logo API" class="text-white">Logo.dev</a>
#         </p>
#       </div>
#     </div>
#   </div>
# </footer>
#
#
#
# <script>
#   document.addEventListener("DOMContentLoaded", function () {
#     const searchInput = document.getElementById("search");
#     const victimItems = document.querySelectorAll("#victim-list .victim-item");
#
#     searchInput.addEventListener("input", function () {
#       const query = this.value.toLowerCase();
#       victimItems.forEach((item) => {
#         const text = item.innerText.toLowerCase();
#         item.classList.toggle("d-none", !text.includes(query));
#       });
#     });
#   });
# </script>
#
#
# <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.3.3/dist/js/bootstrap.bundle.min.js"></script>
#
#
#
# <script>
#   if ('serviceWorker' in navigator) {
#     window.addEventListener('load', function () {
#       navigator.serviceWorker.register('/static/service-worker.js').then(
#         function (registration) {
#           console.log('ServiceWorker registration successful with scope:', registration.scope);
#         }, function (err) {
#           console.log('ServiceWorker registration failed:', err);
#         });
#     });
#   }
#   </script>
#
#
# <script>
#   function setTheme(theme) {
#     document.body.setAttribute('data-bs-theme', theme);
#     document.cookie = `theme=${theme}; path=/; max-age=31536000`; // store preference for 1 year
#
#     // Update all theme toggle icons
#     const icons = [
#       document.getElementById('theme-toggle-icon'),
#       document.getElementById('theme-toggle-icon-mobile')
#     ];
#     icons.forEach(icon => {
#       if (icon) {
#         icon.className = theme === 'dark' ? 'fa-solid fa-toggle-on' : 'fa-solid fa-toggle-off';
#       }
#     });
#   }
#
#   function getThemeFromCookie() {
#     const match = document.cookie.match(/(?:^|; )theme=([^;]*)/);
#     return match ? match[1] : null;
#   }
#
#   document.addEventListener('DOMContentLoaded', () => {
#     const savedTheme = getThemeFromCookie() || 'light';
#     setTheme(savedTheme);
#
#     // Add event listeners to both desktop and mobile toggle buttons
#     ['theme-toggle', 'theme-toggle-mobile'].forEach(id => {
#       const toggleBtn = document.getElementById(id);
#       if (toggleBtn) {
#         toggleBtn.addEventListener('click', () => {
#           const currentTheme = document.body.getAttribute('data-bs-theme');
#           const newTheme = currentTheme === 'dark' ? 'light' : 'dark';
#           setTheme(newTheme);
#         });
#       }
#     });
#   });
# </script>
#
#
#
#
# <!-- Matomo -->
# <script>
#   var _paq = window._paq = window._paq || [];
#   /* tracker methods like "setCustomDimension" should be called before "trackPageView" */
#   _paq.push(['trackPageView']);
#   _paq.push(['enableLinkTracking']);
#   (function() {
#     var u="https://stats.mousqueton.io/";
#     _paq.push(['setTrackerUrl', u+'matomo.php']);
#     _paq.push(['setSiteId', '1']);
#     var d=document, g=d.createElement('script'), s=d.getElementsByTagName('script')[0];
#     g.async=true; g.src=u+'matomo.js'; s.parentNode.insertBefore(g,s);
#   })();
# </script>
# <!-- End Matomo Code -->
# </body>
# </html>

# %%
import re

def parse_ransomware_live_data(html_content):
    """
    ransomware.live HTML 콘텐츠를 파싱하여 통계와 피해자 목록을 반환

    :param html_content: requests를 통해 가져온 HTML 텍스트
    :return: 통계와 피해자 리스트가 포함된 딕셔너리
    """
    kst_timezone = ZoneInfo("Asia/Seoul")
    crawl_time_utc = datetime.now(timezone.utc).isoformat()
    crawl_time_kst = datetime.now(kst_timezone).isoformat()

    soup = BeautifulSoup(html_content, 'html.parser')

    # --- 내부 헬퍼 함수 정의 ---
    def get_victim_details(item):
        try:
            name = item.select_one('strong').get_text(strip=True)
            group = item.select_one('small a span.badge').get_text(strip=True)
            date_container = item.select_one('div.text-body-secondary')
            date_text = date_container.get_text(" ", strip=True) if date_container else ""
            discovery_date_match = re.search(r"Discovery Date: ([\d-]+)", date_text)
            discovery_date = discovery_date_match.group(1) if discovery_date_match else 'N/A'
            attack_date_match = re.search(r"Estimated Attack Date: ([\d-]+)", date_text)
            estimated_attack_date = attack_date_match.group(1) if attack_date_match else 'Not available'
            description_tag = item.select_one('div.bg-body-secondary')
            description = description_tag.get_text(strip=True) if description_tag else 'No description available.'
            country_tag = item.select_one('img[style*="width: 32px"]')
            country = country_tag['alt'] if country_tag and country_tag.has_attr('alt') else 'N/A'
            website_tag = item.select_one('a:has(i.fa-globe-americas)')
            website = website_tag['href'] if website_tag and website_tag.has_attr('href') else 'Not available'
            details_link_tag = item.select_one('a[href*="/id/"]')
            details_url = "https://www.ransomware.live" + details_link_tag['href'] if details_link_tag and details_link_tag.has_attr('href') else 'Not available'
            
            return {
                "company_name": name,
                "ransomware_group": group,
                "discovery_date": discovery_date,
                "estimated_attack_date": estimated_attack_date,
                "description": description,
                "country": country,
                "website": website,
                "details_url": details_url
            }
        except Exception:
            return None

    # --- 1. 통계 데이터 추출 (JavaScript 파싱 방식) ---
    statistics = {}
    try:
        # animateCounter 함수가 포함된 스크립트 태그를 모두 찾습니다.
        scripts = soup.find_all('script')
        script_text = ""
        for script in scripts:
            if 'animateCounter' in script.text:
                script_text = script.text
                break
        
        # 정규표현식을 사용하여 각 카운터의 실제 값을 추출합니다.
        # r"animateCounter\('groupsCounter',\s*\d+,\s*([\d,]+)" 패턴은 다음을 의미합니다:
        # 'groupsCounter'를 찾고, 시작값(0)을 지나, 우리가 원하는 실제 값([\d,]+)을 캡처합니다.
        groups_match = re.search(r"animateCounter\('groupsCounter',\s*\d+,\s*([\d,]+)", script_text)
        victims_match = re.search(r"animateCounter\('victimsCounter',\s*\d+,\s*([\d,]+)", script_text)
        year_match = re.search(r"animateCounter\('victimsThisYearCounter',\s*\d+,\s*([\d,]+)", script_text)
        month_match = re.search(r"animateCounter\('victimsThisMonthCounter',\s*\d+,\s*([\d,]+)", script_text)

        # 캡처된 값에서 쉼표(,)를 제거하고 정수로 변환합니다.
        statistics = {
            "Total Groups": int(groups_match.group(1).replace(',', '')) if groups_match else 0,
            "Total Victims": int(victims_match.group(1).replace(',', '')) if victims_match else 0,
            "Victims This Year": int(year_match.group(1).replace(',', '')) if year_match else 0,
            "Victims This Month": int(month_match.group(1).replace(',', '')) if month_match else 0
        }
    except Exception as e:
        print(f"통계 데이터 추출 중 오류 발생: {e}")
        statistics = {}


    # --- 2. 피해 기업 리스트 추출 ---
    victim_items = soup.select('#victim-list .victim-item')
    victims_list = []
    for item in victim_items:
        victim_data = get_victim_details(item)
        if victim_data:
            victims_list.append(victim_data)

    # --- 최종 결과 반환 ---
    return {
        "crawled_at_utd": crawl_time_utc,
        "crawled_at_kst": crawl_time_kst,
        "statistics": statistics,
        "victims": victims_list
    }

# 이전에 로드한 html_content를 사용하여 함수를 실행하고 결과를 출력합니다.
ransomware_data = parse_ransomware_live_data(html_content)
pprint(ransomware_data)
# Out:
# {'crawled_at_kst': '2025-10-15T22:16:24.599907+09:00',
#  'crawled_at_utd': '2025-10-15T13:16:24.599907+00:00',
#  'statistics': {'Total Groups': 295,
#                 'Total Victims': 22613,
#                 'Victims This Month': 409,
#                 'Victims This Year': 6126},
#  'victims': [{'company_name': 'The North Stonington School District',
#               'country': 'US',
#               'description': 'North Stonington Public Schools have two public '
#                              'schools and 736 students, strives to create a '
#                              'safe e...',
#               'details_url': 'https://www.ransomware.live/id/VGhlIE5vcnRoIFN0b25pbmd0b24gU2Nob29sIERpc3RyaWN0QGludGVybG9jaw==',
#               'discovery_date': '2025-10-15',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Interlock',
#               'website': 'https://northstonington.k12.ct.us'},
#              {'company_name': 'Navigator Business Solutions',
#               'country': 'US',
#               'description': 'Helps companies conquer their industry and '
#                              'business complexity by implementing and '
#                              'supporting the be...',
#               'details_url': 'https://www.ransomware.live/id/TmF2aWdhdG9yIEJ1c2luZXNzIFNvbHV0aW9uc0BwZWFy',
#               'discovery_date': '2025-10-15',
#               'estimated_attack_date': '2025-10-02',
#               'ransomware_group': 'Pear',
#               'website': 'https://nbs-us.com'},
#              {'company_name': 'Unimed do Brasil',
#               'country': 'BR',
#               'description': 'Unimed do Brasil\n'
#                              'Unimed Pelotas is a comprehensive health service '
#                              'center located in Pelotas, Brazil,...',
#               'details_url': 'https://www.ransomware.live/id/VW5pbWVkIGRvIEJyYXNpbEBzYXJjb21h',
#               'discovery_date': '2025-10-15',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Sarcoma',
#               'website': 'Not available'},
#              {'company_name': 'All Truck Transportation Co., Inc.',
#               'country': 'US',
#               'description': 'All Truck Transportation Co., Inc. is an '
#                              'asset-based carrier offering local and regional '
#                              'truckload t...',
#               'details_url': 'https://www.ransomware.live/id/QWxsIFRydWNrIFRyYW5zcG9ydGF0aW9uIENvLiwgSW5jLkBxaWxpbg==',
#               'discovery_date': '2025-10-15',
#               'estimated_attack_date': '2025-08-19',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.alltruck.com'},
#              {'company_name': 'Charles River Properties',
#               'country': 'US',
#               'description': 'Charles River Properties, USA -  a real estate '
#                              'brokerage based in Waltham, Massachusetts, that '
#                              'handl...',
#               'details_url': 'https://www.ransomware.live/id/Q2hhcmxlcyBSaXZlciBQcm9wZXJ0aWVzQHFpbGlu',
#               'discovery_date': '2025-10-15',
#               'estimated_attack_date': '2025-10-14',
#               'ransomware_group': 'Qilin',
#               'website': 'https://charlesriver.properties'},
#              {'company_name': 'ICET Studios',
#               'country': 'N/A',
#               'description': "www.icetstudios.com All'interno delle proprie "
#                              'strutture la ICET Studios dispone di personale '
#                              'qualifi...',
#               'details_url': 'https://www.ransomware.live/id/SUNFVCBTdHVkaW9zQHRoZWdlbnRsZW1lbg==',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Thegentlemen',
#               'website': 'https://www.icetstudios.com'},
#              {'company_name': 'Landmark Management',
#               'country': 'N/A',
#               'description': 'Landmark Management, Inc., manages 90 projects, '
#                              'consisting of 2,462 units across 5 states. '
#                              'Whether y...',
#               'details_url': 'https://www.ransomware.live/id/TGFuZG1hcmsgTWFuYWdlbWVudEBxaWxpbg==',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.landmarkmgtinc.com'},
#              {'company_name': 'New Jersey Property-Liability Insurance '
#                               'Guaranty Association',
#               'country': 'US',
#               'description': 'The New Jersey Property-Liability Insurance '
#                              'Guaranty Association provides essential claims '
#                              'services ...',
#               'details_url': 'https://www.ransomware.live/id/TmV3IEplcnNleSBQcm9wZXJ0eS1MaWFiaWxpdHkgSW5zdXJhbmNlIEd1YXJhbnR5IEFzc29jaWF0aW9uQHFpbGlu',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.njguaranty.org'},
#              {'company_name': 'SFG Technology Sdn Bhd',
#               'country': 'MY',
#               'description': 'SFG Technology specializes in high voltage and '
#                              'medium voltage electrical power systems, solar '
#                              'renewa...',
#               'details_url': 'https://www.ransomware.live/id/U0ZHIFRlY2hub2xvZ3kgU2RuIEJoZEBxaWxpbg==',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.sfg.com.my'},
#              {'company_name': 'WebCut Converting',
#               'country': 'US',
#               'description': 'WebCut Converting, Inc. specializes in contract '
#                              'slitting, laminating, and sheeting services '
#                              'tailored...',
#               'details_url': 'https://www.ransomware.live/id/V2ViQ3V0IENvbnZlcnRpbmdAcWlsaW4=',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.webcutconverting.com'},
#              {'company_name': 'Kecy Metal Technologies',
#               'country': 'US',
#               'description': 'Kecy Metal Technologies (formerly Kecy '
#                              'Corporation) was established in 1988 as a '
#                              'supplier of NVH com...',
#               'details_url': 'https://www.ransomware.live/id/S2VjeSBNZXRhbCBUZWNobm9sb2dpZXNAcWlsaW4=',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.kecymetals.com'},
#              {'company_name': 'Volkswagen Group France',
#               'country': 'FR',
#               'description': 'Volkswagen Group France, a subsidiary of '
#                              'Volkswagen AG, is a prominent player in the '
#                              'automotive indu...',
#               'details_url': 'https://www.ransomware.live/id/Vm9sa3N3YWdlbiBHcm91cCBGcmFuY2VAcWlsaW4=',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.volkswagen.fr/fr.html'},
#              {'company_name': 'Pro-Fab',
#               'country': 'CA',
#               'description': 'Pro Fab, Inc. specializes in custom design and '
#                              'fabrication products and services primarily for '
#                              'clean...',
#               'details_url': 'https://www.ransomware.live/id/UHJvLUZhYkBxaWxpbg==',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.pro-fab.com'},
#              {'company_name': 'Ganther Construction',
#               'country': 'US',
#               'description': 'Established in 1979, GCI is headquartered in '
#                              'Anchorage, Alaska. They are a telecommunications '
#                              'provid...',
#               'details_url': 'https://www.ransomware.live/id/R2FudGhlciBDb25zdHJ1Y3Rpb25Ac2lub2Jp',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': '2025-08-09',
#               'ransomware_group': 'Sinobi',
#               'website': 'Not available'},
#              {'company_name': 'Canapés Mobilier Décoration',
#               'country': 'FR',
#               'description': 'L.LOFT offers a selection of customizable sofas '
#                              'and armchairs in leather, fabric, or microfiber: '
#                              'str...',
#               'details_url': 'https://www.ransomware.live/id/Q2FuYXDDqXMgTW9iaWxpZXIgRMOpY29yYXRpb25AcWlsaW4=',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.l-loft.fr'},
#              {'company_name': 'Prim Saveurs Import Export',
#               'country': 'FR',
#               'description': "PRIM'SAVEURS IMPORT EXPORT SARL was founded on "
#                              'January 22, 2008, 18 years ago. Its legal form '
#                              'is a l...',
#               'details_url': 'https://www.ransomware.live/id/UHJpbSBTYXZldXJzIEltcG9ydCBFeHBvcnRAcWlsaW4=',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Qilin',
#               'website': 'https://public.saintcharlesinternational.com'},
#              {'company_name': 'Rihatec Systemlösungen',
#               'country': 'DE',
#               'description': 'Rihatec specializes in the construction of '
#                              'control cabinets and automation solutions for '
#                              'machines an...',
#               'details_url': 'https://www.ransomware.live/id/UmloYXRlYyBTeXN0ZW1sw7ZzdW5nZW5AcWlsaW4=',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.rihatec.de'},
#              {'company_name': 'Executive Cabinetry',
#               'country': 'US',
#               'description': 'Located in Simpsonville, South Carolina, '
#                              'Executive Cabinetry is an industry leader in '
#                              'semi-custom an...',
#               'details_url': 'https://www.ransomware.live/id/RXhlY3V0aXZlIENhYmluZXRyeUBxaWxpbg==',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.executivecabinetry.com'},
#              {'company_name': 'Alu Perpignan',
#               'country': 'FR',
#               'description': 'ALU Perpignan specializes in PVC and aluminum '
#                              'joinery for individuals and professionals, '
#                              'working on ...',
#               'details_url': 'https://www.ransomware.live/id/QWx1IFBlcnBpZ25hbkBxaWxpbg==',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Qilin',
#               'website': 'https://alu-perpignan.fr'},
#              {'company_name': 'Home/ Schramm Udo Dipl Kfm Steuerberater',
#               'country': 'DE',
#               'description': 'The Marcus Schramm Law Firm offers competent '
#                              'legal advice and an experienced team. We '
#                              'specialize in ...',
#               'details_url': 'https://www.ransomware.live/id/SG9tZS8gU2NocmFtbSBVZG8gRGlwbCBLZm0gU3RldWVyYmVyYXRlckBxaWxpbg==',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.kanzlei-schramm.com'},
#              {'company_name': 'Roger RENARD Entreprise',
#               'country': 'FR',
#               'description': 'A family business founded in 1951 in '
#                              'Amélie-les-Bains (66) by Roger RENARD, we '
#                              'specialize in air con...',
#               'details_url': 'https://www.ransomware.live/id/Um9nZXIgUkVOQVJEIEVudHJlcHJpc2VAcWlsaW4=',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.roger-renard.fr'},
#              {'company_name': 'Hunter Construction Group',
#               'country': 'N/A',
#               'description': 'With a relentless drive to exceed excellence, '
#                              'Jason and West Hunter III, have grown Hunter '
#                              'Construct...',
#               'details_url': 'https://www.ransomware.live/id/SHVudGVyIENvbnN0cnVjdGlvbiBHcm91cEBxaWxpbg==',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.hunterconstructiongroup.com'},
#              {'company_name': 'Urban Linker',
#               'country': 'FR',
#               'description': 'Urban Linker is a recruitment agency that '
#                              'specializes in sourcing and placing digital and '
#                              'tech profe...',
#               'details_url': 'https://www.ransomware.live/id/VXJiYW4gTGlua2VyQHFpbGlu',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.urbanlinker.com'},
#              {'company_name': 'Alqueria',
#               'country': 'CO',
#               'description': 'Productos Naturales de la Sabana S.A.S., doing '
#                              'business as Alquería, is a Colombian company '
#                              'that pro...',
#               'details_url': 'https://www.ransomware.live/id/QWxxdWVyaWFAcWlsaW4=',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.alqueria.com.co'},
#              {'company_name': 'SICE',
#               'country': 'ES',
#               'description': 'SICE is a leading multinational company in '
#                              'technology integration for public infrastructure '
#                              'manageme...',
#               'details_url': 'https://www.ransomware.live/id/U0lDRUBxaWxpbg==',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.sice.com'},
#              {'company_name': 'EURORDIS',
#               'country': 'FR',
#               'description': 'EURORDIS is an organization dedicated to '
#                              'advocating for, empowering, and engaging '
#                              'individuals affect...',
#               'details_url': 'https://www.ransomware.live/id/RVVST1JESVNAcWlsaW4=',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.eurordis.org'},
#              {'company_name': 'PQCNC Hospitals',
#               'country': 'N/A',
#               'description': 'The Perinatal Quality Collaborative of North '
#                              'Carolina is a community-focused organization '
#                              'dedicated ...',
#               'details_url': 'https://www.ransomware.live/id/UFFDTkMgSG9zcGl0YWxzQHFpbGlu',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.pqcnc.org'},
#              {'company_name': 'UT Health Austin',
#               'country': 'US',
#               'description': 'UT Health Austin is the clinical practice of the '
#                              'Dell Medical School located in downtown Austin, '
#                              'off...',
#               'details_url': 'https://www.ransomware.live/id/VVQgSGVhbHRoIEF1c3RpbkBxaWxpbg==',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.uthealthaustin.org'},
#              {'company_name': "ZEF's",
#               'country': 'FI',
#               'description': 'The Center for Development Research (ZEF) is an '
#                              'institute of the University of Bonn, Germany. It '
#                              'sta...',
#               'details_url': 'https://www.ransomware.live/id/WkVGJ3NAcWlsaW4=',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.zef.de'},
#              {'company_name': 'Paris Rétina Vision',
#               'country': 'FR',
#               'description': 'The center features a state-of-the-art technical '
#                              'platform on two levels, allowing for the '
#                              'performanc...',
#               'details_url': 'https://www.ransomware.live/id/UGFyaXMgUsOpdGluYSBWaXNpb25AcWlsaW4=',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.parisretinavision.fr'},
#              {'company_name': 'Buldi',
#               'country': 'N/A',
#               'description': 'Buldi offers a platform for individuals looking '
#                              'to build or expand their homes by configuring '
#                              'their ...',
#               'details_url': 'https://www.ransomware.live/id/QnVsZGlAcWlsaW4=',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.buldi.fr'},
#              {'company_name': 'City of Riviera Beach, Florida',
#               'country': 'US',
#               'description': 'The City of Riviera Beach is committed to making '
#                              "its' website/social media accessible and "
#                              'user-frien...',
#               'details_url': 'https://www.ransomware.live/id/Q2l0eSBvZiBSaXZpZXJhIEJlYWNoLCBGbG9yaWRhQHFpbGlu',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.rivierabch.com'},
#              {'company_name': 'Gittens Healthcare',
#               'country': 'N/A',
#               'description': 'Gittens Healthcare is a leading pharmacy located '
#                              'in Grenada, offering a wide variety of products '
#                              'inc...',
#               'details_url': 'https://www.ransomware.live/id/R2l0dGVucyBIZWFsdGhjYXJlQHFpbGlu',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.gittenshealthcare.com'},
#              {'company_name': 'Trans-World Shipping Service',
#               'country': 'N/A',
#               'description': 'Trans-World Shipping Service, Inc. and Toledo '
#                              'Air Cargo, Inc. are full-service companies '
#                              'offering a ...',
#               'details_url': 'https://www.ransomware.live/id/VHJhbnMtV29ybGQgU2hpcHBpbmcgU2VydmljZUBxaWxpbg==',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.tws-tac.net'},
#              {'company_name': 'Addis',
#               'country': 'ET',
#               'description': 'Addis, Louisiana, located in West Baton Rouge '
#                              'Parish, along the Mississippi River, situated on '
#                              'Louis...',
#               'details_url': 'https://www.ransomware.live/id/QWRkaXNAcWlsaW4=',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.addisla.org'},
#              {'company_name': 'Ditransa',
#               'country': 'CO',
#               'description': 'Ditransa specializes in logistics services aimed '
#                              'at optimizing every stage of the supply chain, '
#                              'from...',
#               'details_url': 'https://www.ransomware.live/id/RGl0cmFuc2FAcWlsaW4=',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.ditransa.com.co'},
#              {'company_name': "LaRosa's",
#               'country': 'US',
#               'description': "LaRosa's, Inc. operates and franchises Italian "
#                              'restaurants and family pizzerias. The company '
#                              'offers ...',
#               'details_url': 'https://www.ransomware.live/id/TGFSb3NhJ3NAcWlsaW4=',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.larosas.com'},
#              {'company_name': 'McGeorge Architecture Interiors',
#               'country': 'US',
#               'description': 'McGeorge Architecture Interiors (MAI) is a full '
#                              'service architecture and interior design firm '
#                              'specia...',
#               'details_url': 'https://www.ransomware.live/id/TWNHZW9yZ2UgQXJjaGl0ZWN0dXJlIEludGVyaW9yc0BxaWxpbg==',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.mcgeorgeai.com'},
#              {'company_name': 'Typology',
#               'country': 'FR',
#               'description': 'Typology offers natural vegan skincare products '
#                              'made in France, focusing on studying the right '
#                              'ingre...',
#               'details_url': 'https://www.ransomware.live/id/VHlwb2xvZ3lAcWlsaW4=',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.typology.com'},
#              {'company_name': '****** embassy D.C',
#               'country': 'N/A',
#               'description': 'Ransom: 200000 USD...',
#               'details_url': 'https://www.ransomware.live/id/KioqKioqIGVtYmFzc3kgRC5DQGRldm1hbg==',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Devman',
#               'website': 'Not available'},
#              {'company_name': 'Sistema Odontológico Privado',
#               'country': 'AR',
#               'description': 'Sistema Odontológico Privado Srl is a company '
#                              'that operates in the Dental Offices industry. It '
#                              'emplo...',
#               'details_url': 'https://www.ransomware.live/id/U2lzdGVtYSBPZG9udG9sw7NnaWNvIFByaXZhZG9AcWlsaW4=',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.sopsrl.com'},
#              {'company_name': 'American Journal of Managed Care',
#               'country': 'US',
#               'description': 'Founded in 1995, The American Journal of Managed '
#                              'Care is a multimedia peer-reviewed, '
#                              'Medline-indexed...',
#               'details_url': 'https://www.ransomware.live/id/QW1lcmljYW4gSm91cm5hbCBvZiBNYW5hZ2VkIENhcmVAcWlsaW4=',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.ajmc.com'},
#              {'company_name': 'Catawba County Government',
#               'country': 'US',
#               'description': 'Catawba County, NC provides an online directory '
#                              'to services around the area including Human '
#                              'Resource...',
#               'details_url': 'https://www.ransomware.live/id/Q2F0YXdiYSBDb3VudHkgR292ZXJubWVudEBxaWxpbg==',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.catawbacountync.gov'},
#              {'company_name': 'HMP Global',
#               'country': 'US',
#               'description': 'For 40 years, the company has built trusted '
#                              'brands including Psych Congress, the premier '
#                              'source for ...',
#               'details_url': 'https://www.ransomware.live/id/SE1QIEdsb2JhbEBxaWxpbg==',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.hmpglobal.com'},
#              {'company_name': 'Morris-Sockle',
#               'country': 'US',
#               'description': 'Morris-Sockle, PLLC is a premier law firm '
#                              'specializing in Family Law and Divorce, with '
#                              'over 40 years...',
#               'details_url': 'https://www.ransomware.live/id/TW9ycmlzLVNvY2tsZUBxaWxpbg==',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.morris-sockle.com'},
#              {'company_name': 'Capitol Construction Services',
#               'country': 'N/A',
#               'description': 'For over 25 years, Capitol Construction '
#                              'Services, Inc. has been one of the most '
#                              'professional general...',
#               'details_url': 'https://www.ransomware.live/id/Q2FwaXRvbCBDb25zdHJ1Y3Rpb24gU2VydmljZXNAcWlsaW4=',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.capitolconstruct.com'},
#              {'company_name': 'Polar-studio',
#               'country': 'SE',
#               'description': 'In 1994, the company became a major energy '
#                              'company, marking the beginning of its rapid '
#                              'development i...',
#               'details_url': 'https://www.ransomware.live/id/UG9sYXItc3R1ZGlvQHFpbGlu',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.polar-studio.hu'},
#              {'company_name': 'H. Gascon',
#               'country': 'N/A',
#               'description': 'Assisted by her colleagues, who are authorized '
#                              'to represent her during hearings and interviews '
#                              'at th...',
#               'details_url': 'https://www.ransomware.live/id/SC4gR2FzY29uQHFpbGlu',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.etude-gascon.fr/accueil'},
#              {'company_name': 'baronespecialtysteel.com',
#               'country': 'US',
#               'description': 'Bar One Specialty Steel specializes in providing '
#                              'high-quality specialty steel products tailored '
#                              'for ...',
#               'details_url': 'https://www.ransomware.live/id/YmFyb25lc3BlY2lhbHR5c3RlZWwuY29tQGluY3JhbnNvbQ==',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Incransom',
#               'website': 'https://baronespecialtysteel.com'},
#              {'company_name': 'Art Guild',
#               'country': 'US',
#               'description': 'Art Guild is a full-service provider of '
#                              'face-to-face marketing an\n'
#                              'd educational programs.\n'
#                              '\n'
#                              'We are re...',
#               'details_url': 'https://www.ransomware.live/id/QXJ0IEd1aWxkQGFraXJh',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Akira',
#               'website': 'Not available'},
#              {'company_name': 'Ostrolenk Faber',
#               'country': 'US',
#               'description': 'Ostrolenk Faber LLP is a premier intellectual '
#                              'property boutique l\n'
#                              'aw firm that has been specializing...',
#               'details_url': 'https://www.ransomware.live/id/T3N0cm9sZW5rIEZhYmVyQGFraXJh',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Akira',
#               'website': 'Not available'},
#              {'company_name': 'Clifford Paper',
#               'country': 'US',
#               'description': 'Clifford Paper is a family-owned business with a '
#                              'deep legacy in the forest products industry, '
#                              'operat...',
#               'details_url': 'https://www.ransomware.live/id/Q2xpZmZvcmQgUGFwZXJAcWlsaW4=',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.cliffordpaper.com'},
#              {'company_name': 'MPM Imports',
#               'country': 'GR',
#               'description': 'MPM IMPORTS LTD is a family owned business which '
#                              'has been established in September 2013 as a spin '
#                              'of...',
#               'details_url': 'https://www.ransomware.live/id/TVBNIEltcG9ydHNAcWlsaW4=',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.mpmimports.com.cy'},
#              {'company_name': 'Radiant Beauty Supplies',
#               'country': 'CA',
#               'description': 'Radiant Beauty Supplies is a Canadian owned and '
#                              'operated business which has been proudly serving '
#                              'the...',
#               'details_url': 'https://www.ransomware.live/id/UmFkaWFudCBCZWF1dHkgU3VwcGxpZXNAcWlsaW4=',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.radiantbeautysupplies.com'},
#              {'company_name': 'Tong Yang Group',
#               'country': 'KR',
#               'description': 'Tong Yang Group is a manufacturer of automotive '
#                              'plastics, sheet metal, and cooling products, as '
#                              'well...',
#               'details_url': 'https://www.ransomware.live/id/VG9uZyBZYW5nIEdyb3VwQHFpbGlu',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.tyg.com.tw'},
#              {'company_name': 'Club Lleuresport',
#               'country': 'ES',
#               'description': 'Club Lleuresport is a versatile organization '
#                              'based in Barcelona dedicated to leisure '
#                              'management, pro...',
#               'details_url': 'https://www.ransomware.live/id/Q2x1YiBMbGV1cmVzcG9ydEBxaWxpbg==',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Qilin',
#               'website': 'https://lleuresport.cat'},
#              {'company_name': 'Repeated Signal Solutions',
#               'country': 'SE',
#               'description': 'Repeated Signal Solutions (RSS) specializes in '
#                              'Cellular, Public Safety, and Wireless Coverage '
#                              'Soluti...',
#               'details_url': 'https://www.ransomware.live/id/UmVwZWF0ZWQgU2lnbmFsIFNvbHV0aW9uc0BxaWxpbg==',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.repeatedsignal.com'},
#              {'company_name': 'Atarfil',
#               'country': 'ES',
#               'description': 'Atarfil Sl is a company that operates in the '
#                              'Repair Services industry. It employs 50to99 '
#                              'people and ...',
#               'details_url': 'https://www.ransomware.live/id/QXRhcmZpbEBxaWxpbg==',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': '2025-10-11',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.atarfil.com'},
#              {'company_name': 'Greenstar Social Marketing',
#               'country': 'PK',
#               'description': 'Greenstar Social Marketing Pakistan (G) Limited '
#                              'is dedicated to improving health outcomes in '
#                              'Pakista...',
#               'details_url': 'https://www.ransomware.live/id/R3JlZW5zdGFyIFNvY2lhbCBNYXJrZXRpbmdAcWlsaW4=',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': '2025-10-11',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.greenstar.org.pk'},
#              {'company_name': 'DuVal & Associates',
#               'country': 'US',
#               'description': 'DuVal & Associates specializes in FDA law, '
#                              'assisting clients in navigating complex '
#                              'regulatory requir...',
#               'details_url': 'https://www.ransomware.live/id/RHVWYWwgJiBBc3NvY2lhdGVzQHFpbGlu',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': '2025-10-11',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.duvalfdalaw.com'},
#              {'company_name': 'Pratt Homes',
#               'country': 'N/A',
#               'description': 'Pratt Homes was founded in 1973 by Len and '
#                              'Lowell, who, along with their partner Uncle '
#                              'Doug, built t...',
#               'details_url': 'https://www.ransomware.live/id/UHJhdHQgSG9tZXNAcWlsaW4=',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': '2025-04-14',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.pratthomes.com'},
#              {'company_name': 'Force Marketing',
#               'country': 'US',
#               'description': 'Force Marketing, USA - Founded in 2006, Force '
#                              'Marketing is a leading marketing technology '
#                              'provider t...',
#               'details_url': 'https://www.ransomware.live/id/Rm9yY2UgTWFya2V0aW5nQHFpbGlu',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.forcemktg.com'},
#              {'company_name': 'DV Hardwoods',
#               'country': 'CA',
#               'description': 'DV Hardwoods, Canada -  an undisputed leader in '
#                              'the hardwood lumber sector. In short, the '
#                              'company de...',
#               'details_url': 'https://www.ransomware.live/id/RFYgSGFyZHdvb2RzQHFpbGlu',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.boisdv.ca'},
#              {'company_name': 'Plast-O-Matic Valves',
#               'country': 'US',
#               'description': 'Plast-O-Matic Valves, Inc. specializes in the '
#                              'development and man\n'
#                              'ufacturing of high-quality thermop...',
#               'details_url': 'https://www.ransomware.live/id/UGxhc3QtTy1NYXRpYyBWYWx2ZXNAYWtpcmE=',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Akira',
#               'website': 'Not available'},
#              {'company_name': 'Blood Bank Computer Systems',
#               'country': 'US',
#               'description': 'BBCS Inc specializes in innovative blood banking '
#                              'software and bio\n'
#                              'logics management solutions, desig...',
#               'details_url': 'https://www.ransomware.live/id/Qmxvb2QgQmFuayBDb21wdXRlciBTeXN0ZW1zQGFraXJh',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Akira',
#               'website': 'Not available'},
#              {'company_name': 'M&E Global Group',
#               'country': 'US',
#               'description': 'M&E Global Group, Inc. USA -  specializes in '
#                              'point of purchase display and store fixture '
#                              'manufacturi...',
#               'details_url': 'https://www.ransomware.live/id/TSZFIEdsb2JhbCBHcm91cEBxaWxpbg==',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.megroupinc.com'},
#              {'company_name': 'Leprohon (Image !)',
#               'country': 'N/A',
#               'description': 'Leprohon Inc is a company that operates in the '
#                              'Commercial & Residential Construction industry. '
#                              'It em...',
#               'details_url': 'https://www.ransomware.live/id/TGVwcm9ob24gKEltYWdlICEpQG1lZHVzYQ==',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': '2025-10-09',
#               'ransomware_group': 'Medusa',
#               'website': 'Not available'},
#              {'company_name': 'LA VOIE EXPRESS',
#               'country': 'MA',
#               'description': 'LA VOIE EXPRESS offers comprehensive logistics '
#                              'services including messaging, transport, '
#                              'e-commerce s...',
#               'details_url': 'https://www.ransomware.live/id/TEEgVk9JRSBFWFBSRVNTQG1lZHVzYQ==',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': '2025-10-12',
#               'ransomware_group': 'Medusa',
#               'website': 'Not available'},
#              {'company_name': 'Design To Print',
#               'country': 'US',
#               'description': 'Printdaddy design printing is known for its '
#                              'excellence and expertise in indoor, outdoor '
#                              'advertising,...',
#               'details_url': 'https://www.ransomware.live/id/RGVzaWduIFRvIFByaW50QG1lZHVzYQ==',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': '2025-10-12',
#               'ransomware_group': 'Medusa',
#               'website': 'Not available'},
#              {'company_name': 'EcoPetróleo',
#               'country': 'BR',
#               'description': 'EcoPetróleo is dedicated to providing petroleum '
#                              'products while actively engaging in '
#                              'environmental co...',
#               'details_url': 'https://www.ransomware.live/id/RWNvUGV0csOzbGVvQG1lZHVzYQ==',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': '2025-10-12',
#               'ransomware_group': 'Medusa',
#               'website': 'Not available'},
#              {'company_name': 'Cemtrex',
#               'country': 'US',
#               'description': 'Founded in 2004 and headquartered in Brooklyn, '
#                              'New York, Cemtrex is a global, diversified '
#                              'industrial...',
#               'details_url': 'https://www.ransomware.live/id/Q2VtdHJleEBtZWR1c2E=',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': '2025-10-13',
#               'ransomware_group': 'Medusa',
#               'website': 'Not available'},
#              {'company_name': 'Fountains Condominium Operations',
#               'country': 'N/A',
#               'description': 'Fountains Condominium Operations Inc. is an '
#                              'in-house management company dedicated to '
#                              'ensuring the be...',
#               'details_url': 'https://www.ransomware.live/id/Rm91bnRhaW5zIENvbmRvbWluaXVtIE9wZXJhdGlvbnNAZHJhZ29uZm9yY2U=',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': '2025-10-13',
#               'ransomware_group': 'Dragonforce',
#               'website': 'https://www.fcocondo.com'},
#              {'company_name': 'Speed Inter Transport',
#               'country': 'N/A',
#               'description': '[AI generated] Speed Inter Transport is a '
#                              'logistics and transportation company that '
#                              'provides high-qu...',
#               'details_url': 'https://www.ransomware.live/id/U3BlZWQgSW50ZXIgVHJhbnNwb3J0QGRpcmV3b2xm',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': '2025-10-05',
#               'ransomware_group': 'Direwolf',
#               'website': 'Not available'},
#              {'company_name': 'Miguel Veiga, Neiva Santos e Associados.',
#               'country': 'PT',
#               'description': '[AI generated] N/A...',
#               'details_url': 'https://www.ransomware.live/id/TWlndWVsIFZlaWdhLCBOZWl2YSBTYW50b3MgZSBBc3NvY2lhZG9zLkBkaXJld29sZg==',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': '2025-10-05',
#               'ransomware_group': 'Direwolf',
#               'website': 'Not available'},
#              {'company_name': 'Schedler-translog',
#               'country': 'AT',
#               'description': 'Since the company was founded in 1984, the '
#                              'company has been characterized by its family '
#                              'structure, u...',
#               'details_url': 'https://www.ransomware.live/id/U2NoZWRsZXItdHJhbnNsb2dAY29pbmJhc2VjYXJ0ZWw=',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Coinbasecartel',
#               'website': 'https://schedler-translog.de'},
#              {'company_name': 'Karnes Electric Cooperative',
#               'country': 'US',
#               'description': 'Karnes Electric Cooperative, USA is a '
#                              'not-for-profit electric distribution utility '
#                              'that serves 12 co...',
#               'details_url': 'https://www.ransomware.live/id/S2FybmVzIEVsZWN0cmljIENvb3BlcmF0aXZlQHFpbGlu',
#               'discovery_date': '2025-10-14',
#               'estimated_attack_date': '2025-10-10',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.karnesec.org'},
#              {'company_name': 'Business Integra',
#               'country': 'US',
#               'description': 'Business Integra provides solutions for '
#                              'scientific, engineering, \n'
#                              'information technology, cyber-secu...',
#               'details_url': 'https://www.ransomware.live/id/QnVzaW5lc3MgSW50ZWdyYUBha2lyYQ==',
#               'discovery_date': '2025-10-13',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Akira',
#               'website': 'Not available'},
#              {'company_name': 'Bank3',
#               'country': 'N/A',
#               'description': "Bank3, USA - it's a disaster for the clients. "
#                              'Bank3 is a community-driven banking institution '
#                              'offeri...',
#               'details_url': 'https://www.ransomware.live/id/QmFuazNAcWlsaW4=',
#               'discovery_date': '2025-10-13',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.bank3.com'},
#              {'company_name': 'San Bernard Electric Cooperative',
#               'country': 'US',
#               'description': 'San Bernard Electric Cooperative, USA - offers a '
#                              'range of services including outage reporting, '
#                              'gener...',
#               'details_url': 'https://www.ransomware.live/id/U2FuIEJlcm5hcmQgRWxlY3RyaWMgQ29vcGVyYXRpdmVAcWlsaW4=',
#               'discovery_date': '2025-10-13',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.sbec.org'},
#              {'company_name': 'BHI Co., Ltd.',
#               'country': 'KR',
#               'description': 'BHI Co., Ltd. engages in the manufacturing and '
#                              'supplying of power plant equipment worldwide. It '
#                              'offe...',
#               'details_url': 'https://www.ransomware.live/id/QkhJIENvLiwgTHRkLkBxaWxpbg==',
#               'discovery_date': '2025-10-13',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Qilin',
#               'website': 'https:// www.bhi.co.kr'},
#              {'company_name': 'Indaco Warna Dunia',
#               'country': 'ID',
#               'description': 'Indonesia\n'
#                              'Wholesale building materials\n'
#                              'Revenue  6,4 million $\n'
#                              'Employees  281...',
#               'details_url': 'https://www.ransomware.live/id/SW5kYWNvIFdhcm5hIER1bmlhQG5vdmE=',
#               'discovery_date': '2025-10-13',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Nova',
#               'website': 'Not available'},
#              {'company_name': 'www.mercantetubos.com.br',
#               'country': 'BR',
#               'description': 'Mangueira Indústria e Comércio de Tubos e Aços '
#                              'Especiais Ltda. was founded on October 3, 1972, '
#                              'with ...',
#               'details_url': 'https://www.ransomware.live/id/d3d3Lm1lcmNhbnRldHVib3MuY29tLmJyQGFscGhhbG9ja2Vy',
#               'discovery_date': '2025-10-13',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Alphalocker',
#               'website': 'https://www.mercantetubos.com.br'},
#              {'company_name': 'SourceOne Corporation',
#               'country': 'N/A',
#               'description': 'SourceOne Corporation, USA - specializes in '
#                              'managing all phases of Outside Plant (OSP) and '
#                              'Inside Pl...',
#               'details_url': 'https://www.ransomware.live/id/U291cmNlT25lIENvcnBvcmF0aW9uQHFpbGlu',
#               'discovery_date': '2025-10-13',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Qilin',
#               'website': 'https:// www.sourceonecorp.com'},
#              {'company_name': 'hautsdefrance.fr',
#               'country': 'FR',
#               'description': 'The Regional Council manages regional programs '
#                              '(economy, transport, education, vocational '
#                              'training, ...',
#               'details_url': 'https://www.ransomware.live/id/aGF1dHNkZWZyYW5jZS5mckBxaWxpbg==',
#               'discovery_date': '2025-10-13',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Qilin',
#               'website': 'https://www.hautsdefrance.fr'},
#              {'company_name': 'Furuno Electric',
#               'country': 'JP',
#               'description': 'Furuno Electric FURUNO strives to contribute to '
#                              'realisation of the pleasant society filled with '
#                              'safe...',
#               'details_url': 'https://www.ransomware.live/id/RnVydW5vIEVsZWN0cmljQHJoeXNpZGE=',
#               'discovery_date': '2025-10-13',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Rhysida',
#               'website': 'Not available'},
#              {'company_name': 'Undefasa',
#               'country': 'ES',
#               'description': 'Ceramicists since 1967We are a family-run '
#                              'business that was established in the heat of the '
#                              'Sierra, a...',
#               'details_url': 'https://www.ransomware.live/id/VW5kZWZhc2FAYmxhY2tuZXZhcw==',
#               'discovery_date': '2025-10-13',
#               'estimated_attack_date': '2025-10-09',
#               'ransomware_group': 'Blacknevas',
#               'website': 'https://www.undefasa.com'},
#              {'company_name': 'North Stonington Elementary School',
#               'country': 'US',
#               'description': 'North Stonington Public Schools have two public '
#                              'schools and 736 students, strives to create a '
#                              'safe e...',
#               'details_url': 'https://www.ransomware.live/id/Tm9ydGggU3RvbmluZ3RvbiBFbGVtZW50YXJ5IFNjaG9vbEBpbnRlcmxvY2s=',
#               'discovery_date': '2025-10-13',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Interlock',
#               'website': 'https://northstonington.k12.ct.us'},
#              {'company_name': 'relationmedia.dk',
#               'country': 'DK',
#               'description': 'Revenue: $<5kk | Leak Size: xx GB | Status: '
#                              'Published...',
#               'details_url': 'https://www.ransomware.live/id/cmVsYXRpb25tZWRpYS5ka0BvYnNjdXJh',
#               'discovery_date': '2025-10-13',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Obscura',
#               'website': 'https://relationmedia.dk'},
#              {'company_name': 'meamargroup.com',
#               'country': 'EG',
#               'description': 'Revenue: $30kk | Leak Size: xx GB | Status: '
#                              'Published...',
#               'details_url': 'https://www.ransomware.live/id/bWVhbWFyZ3JvdXAuY29tQG9ic2N1cmE=',
#               'discovery_date': '2025-10-13',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Obscura',
#               'website': 'https://meamargroup.com'},
#              {'company_name': 'plazadental.com',
#               'country': 'US',
#               'description': 'Revenue: $<5kk | Leak Size: xx GB | Status: '
#                              'Published...',
#               'details_url': 'https://www.ransomware.live/id/cGxhemFkZW50YWwuY29tQG9ic2N1cmE=',
#               'discovery_date': '2025-10-13',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Obscura',
#               'website': 'https://plazadental.com'},
#              {'company_name': 'heavenly-dental.com',
#               'country': 'US',
#               'description': 'Revenue: $<5kk | Leak Size: xx GB | Status: '
#                              'Published...',
#               'details_url': 'https://www.ransomware.live/id/aGVhdmVubHktZGVudGFsLmNvbUBvYnNjdXJh',
#               'discovery_date': '2025-10-13',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Obscura',
#               'website': 'https://heavenly-dental.com'},
#              {'company_name': 'thefixingcompany.com',
#               'country': 'IE',
#               'description': 'Revenue: $<5kk | Leak Size: xx GB | Status: '
#                              'Published...',
#               'details_url': 'https://www.ransomware.live/id/dGhlZml4aW5nY29tcGFueS5jb21Ab2JzY3VyYQ==',
#               'discovery_date': '2025-10-13',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Obscura',
#               'website': 'https://thefixingcompany.com'},
#              {'company_name': 'eastdesign.com.my',
#               'country': 'MY',
#               'description': 'Revenue: $<5kk | Leak Size: xx GB | Status: '
#                              'Published...',
#               'details_url': 'https://www.ransomware.live/id/ZWFzdGRlc2lnbi5jb20ubXlAb2JzY3VyYQ==',
#               'discovery_date': '2025-10-13',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Obscura',
#               'website': 'https://eastdesign.com.my'},
#              {'company_name': 'espectral.pt',
#               'country': 'PT',
#               'description': 'Revenue: $<5kk | Leak Size: xx GB | Status: '
#                              'Published...',
#               'details_url': 'https://www.ransomware.live/id/ZXNwZWN0cmFsLnB0QG9ic2N1cmE=',
#               'discovery_date': '2025-10-13',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Obscura',
#               'website': 'https://espectral.pt'},
#              {'company_name': 'michigancityin.gov',
#               'country': 'US',
#               'description': 'Revenue: ?? | Leak Size: 450 GB | Status: '
#                              'Published...',
#               'details_url': 'https://www.ransomware.live/id/bWljaGlnYW5jaXR5aW4uZ292QG9ic2N1cmE=',
#               'discovery_date': '2025-10-13',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Obscura',
#               'website': 'https://michigancityin.gov'},
#              {'company_name': 'DragonForce team hurry to notify you about new '
#                               'public available registration '
#                               'panel!\\n\\http...',
#               'country': 'N/A',
#               'description': 'DragonForce team hurry to notify you about new '
#                              'public available registration '
#                              'panel!\\n\\http://dragong...',
#               'details_url': 'https://www.ransomware.live/id/RHJhZ29uRm9yY2UgdGVhbSBodXJyeSB0byBub3RpZnkgeW91IGFib3V0IG5ldyBwdWJsaWMgYXZhaWxhYmxlIHJlZ2lzdHJhdGlvbiBwYW5lbCFcblxodHRwLi4uQGRyYWdvbmZvcmNl',
#               'discovery_date': '2025-10-13',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Dragonforce',
#               'website': 'https://dragongoztkdfmnd7jkchznd3fvkpdmeh4vhbt6p3usrlsoy5dw2bhyd.onion'},
#              {'company_name': 'PLC-Transportation',
#               'country': 'N/A',
#               'description': 'PLC Trans is an established company in the field '
#                              'of international transport and logistics. In the '
#                              'la...',
#               'details_url': 'https://www.ransomware.live/id/UExDLVRyYW5zcG9ydGF0aW9uQGNvaW5iYXNlY2FydGVs',
#               'discovery_date': '2025-10-13',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Coinbasecartel',
#               'website': 'https://plc-trans.com'},
#              {'company_name': 'dsv.com',
#               'country': 'DK',
#               'description': 'DSV is a global transport and logistics company '
#                              'that provides and manages supply chain solutions '
#                              'for...',
#               'details_url': 'https://www.ransomware.live/id/ZHN2LmNvbUBjb2luYmFzZWNhcnRlbA==',
#               'discovery_date': '2025-10-13',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Coinbasecartel',
#               'website': 'https://dsv.com'},
#              {'company_name': 'Kuehne + Nagel',
#               'country': 'CH',
#               'description': 'With more than 82,000 employees at almost 1,300 '
#                              'sites in close to 100 countries, the '
#                              'Kuehne+Nagel Gr...',
#               'details_url': 'https://www.ransomware.live/id/S3VlaG5lICsgTmFnZWxAY29pbmJhc2VjYXJ0ZWw=',
#               'discovery_date': '2025-10-13',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Coinbasecartel',
#               'website': 'https://kuehne-nagel.com'},
#              {'company_name': 'Altas Temizlik',
#               'country': 'TR',
#               'description': '[AI generated] N/A...',
#               'details_url': 'https://www.ransomware.live/id/QWx0YXMgVGVtaXpsaWtAYmxhY2tzaHJhbnRhYw==',
#               'discovery_date': '2025-10-13',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Blackshrantac',
#               'website': 'Not available'}]}

# %% [markdown]
# 파이썬 파일로 바꾼뒤 실행 결과

# %% [markdown]
# 'https://www.ransomware.live/'에서 데이터 크롤링을 시작합니다...
#
# ✅ [https://www.ransomware.live/] - HTML 콘텐츠 로드 성공
#
# 크롤링 성공! 데이터 파싱을 시작합니다...
#
# --- 파싱 완료된 데이터 ---
# ```python
# {'crawled_at_kst': '2025-10-15T22:20:00.271465+09:00',
#  'crawled_at_utc': '2025-10-15T13:20:00.271465+00:00',
#  'statistics': {'Total Groups': 295,
#                 'Total Victims': 22614,
#                 'Victims This Month': 410,
#                 'Victims This Year': 6127},
#  'victims': [{'company_name': 'www.cbsaust.org.au',
#               'country': 'AU',
#               'description': 'CBS Tasmania is a not-for-profit organization '
#                              'that provides personalized aged care and '
#                              'disability se...',
#               'details_url': 'https://www.ransomware.live/id/d3d3LmNic2F1c3Qub3JnLmF1QGx5bng=',
#               'discovery_date': '2025-10-15',
#               'estimated_attack_date': '2025-10-10',
#               'ransomware_group': 'Lynx',
#               'website': 'https://www.cbsaust.org.au'},
#              {'company_name': 'The North Stonington School District',
#               'country': 'US',
#               'description': 'North Stonington Public Schools have two public '
#                              'schools and 736 students, strives to create a '
#                              'safe e...',
#               'details_url': 'https://www.ransomware.live/id/VGhlIE5vcnRoIFN0b25pbmd0b24gU2Nob29sIERpc3RyaWN0QGludGVybG9jaw==',
#               'discovery_date': '2025-10-15',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Interlock',
#               'website': 'https://northstonington.k12.ct.us'},
#              ...
#              {'company_name': 'dsv.com',
#               'country': 'DK',
#               'description': 'DSV is a global transport and logistics company '
#                              'that provides and manages supply chain solutions '
#                              'for...',
#               'details_url': 'https://www.ransomware.live/id/ZHN2LmNvbUBjb2luYmFzZWNhcnRlbA==',
#               'discovery_date': '2025-10-13',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Coinbasecartel',
#               'website': 'https://dsv.com'},
#              {'company_name': 'Kuehne + Nagel',
#               'country': 'CH',
#               'description': 'With more than 82,000 employees at almost 1,300 '
#                              'sites in close to 100 countries, the '
#                              'Kuehne+Nagel Gr...',
#               'details_url': 'https://www.ransomware.live/id/S3VlaG5lICsgTmFnZWxAY29pbmJhc2VjYXJ0ZWw=',
#               'discovery_date': '2025-10-13',
#               'estimated_attack_date': 'Not available',
#               'ransomware_group': 'Coinbasecartel',
#               'website': 'https://kuehne-nagel.com'}]}
# ```
#
# 🎉 프로그램이 성공적으로 실행되었습니다.
